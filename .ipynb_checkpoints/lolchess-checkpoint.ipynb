# %%
from urllib.request import urlopen
from selenium import webdriver as wd 
from bs4 import BeautifulSoup
from tqdm import tqdm

import itertools
import pandas as pd
import requests
import time
import copy
import re

# %%
#1. 조합을 우선적으로 정리하기
#2. 조합에 필요한 아이템 정리하기
#3. 조합의 승률을 정리하기
# 이후 상관 관계 및 SVD를 이용하여 추천 시스템 만들기

# %% [markdown]
# ## 현재 존재하는 아이템 리스트 가져오기

# %%
def make_itemlist():
    url = 'https://lolchess.gg/items'
    hdr = {'Accept-Language' : 'Ko_KR', 'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36'}
    req = requests.get(url, headers = hdr)
    html = req.text
    soup = BeautifulSoup(html, 'html.parser')

    itemdict = {}
    for i in soup.find_all('div',{'class':'col-sm-6'}):
        arr = []
        for index, item in enumerate(i.select('img')):
            if index == 2:
                itemdict[item.get('alt')] = arr[:]
            else:
                arr.append(item.get('alt'))
        arr.clear()
    return itemdict

# %% [markdown]
# ## 아이템 리스트 불러오기

# %%
item_list = make_itemlist()
a = set()
for key, value in item_list.items():
    for i in value:
        a.add(i)
print(a)
# Out:
# {'쓸데없이 큰 지팡이', '곡궁', '연습용 장갑', '여신의 눈물', '뒤집개', 'B.F. 대검', '음전자 망토', '쇠사슬 조끼', '거인의 허리띠'}

# %% [markdown]
# ## 합친 아이템을 분해해서 구성요소를 볼 수 있는 함수

# %%
def decomposition_item(item_list,arr):
    small_item = []
    for full in arr:
        if full in item_list:
            small_item.append(item_list[full][0])
            small_item.append(item_list[full][1])
        else:
            small_item.append(full)
        small_item.sort()

    return small_item

# %% [markdown]
# ## Beautiful Soup을 이용하여서 상위 티어의 아이템/ 시너지/ 승률 가져오기

# %%
# url을 이용하여서 html을 받아오는 함수
def rcv_sp(hdr, url, check):
    req = requests.get(url, headers = hdr)
    sp = BeautifulSoup(req.text, 'html.parser')
    
    if check == 1:
        return sp
    else : 
        return sp.find('div',{'class' : 'profile__match-history-v2__filters'}).select('a')[1]['href']

#해당 게임의 아이템을 받아오는 함수     
def rcv_items(itemsp):
    itemlist = []
    for i in itemsp:
        tp = i.select('.item')
        if len(tp) == 0:
            continue
        for items in tp:
            itemlist.append(items['title'])
    return itemlist

#해당 게임의 조합을 받아오는 함수
def rcv_traits(traitsp):
    traitslist = []
    for i in traitsp:
        traitslist.append(i.find('img')['alt'])
        
    return traitslist
    
def main_func():
    url = 'https://lolchess.gg/leaderboards'
    hdr = {'Accept-Language' : 'Ko_KR', 'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36'}
    req = requests.get(url, headers = hdr)
    soup = (BeautifulSoup(req.text,'html.parser'))
    #데이터를 저장할 배열
    save_data = []
    for i in tqdm(soup.find('tbody').select('a')):
        #처음에 i 에서 유저의 정보를 받아서 이 유저의 랭크의 soup를 받아온다
        sp = rcv_sp(hdr,rcv_sp(hdr,i['href'],0),1)
        #하나씩 저장
        temp_data = []
        for j in sp.select('.profile__match-history-v2__item'):
            rank = j.find('div',{'class':'placement'}).text.strip()[1]
            traits = rcv_traits(j.select('.tft-hexagon-image'))
            items = rcv_items(j.select('.items'))
            temp_data.append(rank)
            temp_data.append(traits)
            temp_data.append(items)
            save_data.append(temp_data[:])
            temp_data.clear()
    return save_data

# %%
data = main_func()
# Out:
# 100%|██████████| 100/100 [02:36<00:00,  1.56s/it]

# %%
cp = copy.deepcopy(data)

# %%
final_set[0]
# Out:
# [['3 조율자',
#   '3 달빛',
#   '3 사냥꾼',
#   '2 신성',
#   '2 영혼',
#   '2 신비술사',
#   '2 싸움꾼',
#   '1 닌자',
#   '1 추방자'],
#  ['1음전자 망토',
#   '3연습용 장갑',
#   '1쇠사슬 조끼',
#   '1곡궁',
#   '3B.F. 대검',
#   '2여신의 눈물',
#   '2쓸데없이 큰 지팡이',
#   '3거인의 허리띠']]

# %% [markdown]
# ## 아이템의 갯수를 비교해서 가장 근접한 조합을 넣는다.

# %%
def match_item(final_set, temp):
    tp = []
    max_score = 0
    now = -1
    for i, v in enumerate(final_set):
        score = 0
        total = 0
        for value in temp:
            s = int(value[0])
            total += s
            item = value[1:]
            for it in v[1]:
#                 print(f'it : {it[1:]}, item : {item}')
                if it[1:] == item:
                    score += min(s,int(it[0]))
                    break
        if max_score < score:
            max_score = score
            now = i
    
    if now != -1:
        tp.append(final_set[14][now])
        tp.append(round(max_score/total,2))
    else:
        tp.append(0)
        tp.append(0)
    
    return tp

# %%
cp = copy.deepcopy(data)
for i in cp:
    full_item = i.pop()
    small_item = decomposition_item(item_list,full_item)
    traits = i.pop()
    
    sm = list(set(small_item))
    for index, value in enumerate(sm):
        #이미 분할 되었으면 break
        if value[0].isnumeric():
            break
        tp_1 = sm[index]
        sm[index]= (str(small_item.count(value)))+tp_1
        
    johab = match_item(final_set, sm)
    
    
    i.append(sm)
    i.append(johab[0])
    i[1].sort(reverse=True)

for i in cp:
    print(i)
#     print()
# Out:
# ['4', ['3음전자 망토', '3연습용 장갑', '3여신의 눈물', '3곡궁', '2쓸데없이 큰 지팡이', '2B.F. 대검'], '나무정령요술사']
# ['5', ['4음전자 망토', '4쇠사슬 조끼', '3곡궁', '2연습용 장갑', '2거인의 허리띠', '2B.F. 대검', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1뒤집개'], '황혼']
# ['3', ['4B.F. 대검', '3연습용 장갑', '3여신의 눈물', '3쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2곡궁', '1음전자 망토', '1뒤집개', '1거인의 허리띠'], '명사수귀감']
# ['1', ['3여신의 눈물', '3쓸데없이 큰 지팡이', '3쇠사슬 조끼', '3곡궁', '2연습용 장갑', '1음전자 망토', '1B.F. 대검'], '황혼']
# ['3', ['4연습용 장갑', '4B.F. 대검', '3음전자 망토', '3여신의 눈물', '3쇠사슬 조끼', '1쓸데없이 큰 지팡이', '1곡궁', '1거인의 허리띠'], '조율자결투가']
# ['3', ['3쓸데없이 큰 지팡이', '3쇠사슬 조끼', '3거인의 허리띠', '2음전자 망토', '2뒤집개', '1연습용 장갑', '1여신의 눈물', '1곡궁', '1B.F. 대검'], '황혼']
# ['2', ['3쓸데없이 큰 지팡이', '3쇠사슬 조끼', '3거인의 허리띠', '2음전자 망토', '2여신의 눈물', '2B.F. 대검', '1연습용 장갑', '1뒤집개', '1곡궁'], '황혼']
# ['2', ['6음전자 망토', '6연습용 장갑', '4B.F. 대검', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2거인의 허리띠', '1여신의 눈물', '1뒤집개', '1곡궁'], '광신도']
# ['2', ['6연습용 장갑', '5쓸데없이 큰 지팡이', '5곡궁', '3여신의 눈물', '3쇠사슬 조끼', '2음전자 망토', '2거인의 허리띠', '2B.F. 대검'], '황혼']
# ['2', ['7쇠사슬 조끼', '3연습용 장갑', '2음전자 망토', '2거인의 허리띠', '1쓸데없이 큰 지팡이', '1뒤집개', '1곡궁', '1B.F. 대검'], '황혼']
# ['4', ['3여신의 눈물', '3B.F. 대검', '2음전자 망토', '2쇠사슬 조끼', '2뒤집개', '2거인의 허리띠', '1연습용 장갑', '1쓸데없이 큰 지팡이', '1곡궁'], '나무정령요술사']
# ['1', ['4뒤집개', '4곡궁', '3거인의 허리띠', '2음전자 망토', '2연습용 장갑', '2여신의 눈물', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1B.F. 대검'], '그림자닌자']
# ['8', ['4쓸데없이 큰 지팡이', '3연습용 장갑', '2음전자 망토', '2쇠사슬 조끼', '2거인의 허리띠', '1여신의 눈물', '1곡궁', '1B.F. 대검'], '황혼']
# ['4', ['4쓸데없이 큰 지팡이', '3쇠사슬 조끼', '3곡궁', '2음전자 망토', '2연습용 장갑', '1여신의 눈물', '1거인의 허리띠', '1B.F. 대검'], '황혼']
# ['2', ['4여신의 눈물', '4쓸데없이 큰 지팡이', '4거인의 허리띠', '2쇠사슬 조끼', '2곡궁', '1음전자 망토', '1B.F. 대검'], '결투가']
# ['4', ['3곡궁', '2음전자 망토', '2연습용 장갑', '2여신의 눈물', '2거인의 허리띠', '2B.F. 대검', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1뒤집개'], '나무정령요술사']
# ['3', ['4쓸데없이 큰 지팡이', '3음전자 망토', '3연습용 장갑', '3곡궁', '2쇠사슬 조끼', '2B.F. 대검', '1뒤집개'], '나무정령싸움꾼']
# ['3', ['4연습용 장갑', '4여신의 눈물', '3쇠사슬 조끼', '2거인의 허리띠', '1음전자 망토', '1쓸데없이 큰 지팡이', '1곡궁', '1B.F. 대검'], '나무정령요술사']
# ['6', ['5여신의 눈물', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2거인의 허리띠', '1음전자 망토', '1연습용 장갑'], '나무정령요술사']
# ['1', ['4B.F. 대검', '3쇠사슬 조끼', '3거인의 허리띠', '2음전자 망토', '2여신의 눈물', '2곡궁', '1연습용 장갑', '1쓸데없이 큰 지팡이', '1뒤집개'], '명사수귀감']
# ['5', ['4B.F. 대검', '3음전자 망토', '3쓸데없이 큰 지팡이', '3곡궁', '2연습용 장갑', '2여신의 눈물', '2쇠사슬 조끼', '1거인의 허리띠'], '명사수귀감']
# ['6', ['4쓸데없이 큰 지팡이', '4쇠사슬 조끼', '3여신의 눈물', '1연습용 장갑'], '황혼']
# ['1', ['8거인의 허리띠', '6쓸데없이 큰 지팡이', '3쇠사슬 조끼', '2연습용 장갑', '2여신의 눈물', '1B.F. 대검'], '싸움꾼']
# ['2', ['3여신의 눈물', '3쇠사슬 조끼', '3곡궁', '2음전자 망토', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2거인의 허리띠', '1B.F. 대검'], '신성조율자']
# ['4', ['5쓸데없이 큰 지팡이', '3여신의 눈물', '3거인의 허리띠', '3B.F. 대검', '2음전자 망토', '2쇠사슬 조끼', '1연습용 장갑', '1곡궁'], '달빛사냥꾼']
# ['4', ['3여신의 눈물', '3B.F. 대검', '2쇠사슬 조끼', '2곡궁', '2거인의 허리띠', '1음전자 망토', '1연습용 장갑', '1쓸데없이 큰 지팡이', '1뒤집개'], '나무정령요술사']
# ['4', ['3쇠사슬 조끼', '3곡궁', '2음전자 망토', '2연습용 장갑', '2여신의 눈물', '2B.F. 대검', '1쓸데없이 큰 지팡이', '1거인의 허리띠'], '신성조율자']
# ['2', ['7쓸데없이 큰 지팡이', '4쇠사슬 조끼', '3음전자 망토', '2곡궁', '2B.F. 대검', '1연습용 장갑', '1여신의 눈물', '1거인의 허리띠'], '황혼']
# ['6', ['3쇠사슬 조끼', '3거인의 허리띠', '2여신의 눈물', '2B.F. 대검', '1음전자 망토', '1연습용 장갑', '1쓸데없이 큰 지팡이'], '달빛사냥꾼']
# ['5', ['3음전자 망토', '3쓸데없이 큰 지팡이', '3쇠사슬 조끼', '1연습용 장갑', '1여신의 눈물', '1곡궁', '1거인의 허리띠', '1B.F. 대검'], '황혼']
# ['1', ['7여신의 눈물', '3연습용 장갑', '3쓸데없이 큰 지팡이', '3B.F. 대검', '2곡궁', '1음전자 망토', '1쇠사슬 조끼', '1거인의 허리띠'], '달빛사냥꾼']
# ['3', ['5곡궁', '3여신의 눈물', '2음전자 망토', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2거인의 허리띠', '1B.F. 대검'], '신성조율자']
# ['1', ['5거인의 허리띠', '4쇠사슬 조끼', '4곡궁', '4B.F. 대검', '3쓸데없이 큰 지팡이', '2여신의 눈물', '1음전자 망토', '1연습용 장갑'], '싸움꾼']
# ['2', ['5B.F. 대검', '4곡궁', '2음전자 망토', '2연습용 장갑', '2뒤집개', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1거인의 허리띠'], '명사수귀감']
# ['2', ['7곡궁', '5음전자 망토', '5연습용 장갑', '3거인의 허리띠', '2여신의 눈물', '2쇠사슬 조끼', '1쓸데없이 큰 지팡이', '1B.F. 대검'], '달빛사냥꾼']
# ['1', ['5거인의 허리띠', '4여신의 눈물', '3쇠사슬 조끼', '3곡궁', '2음전자 망토', '2쓸데없이 큰 지팡이', '1뒤집개', '1B.F. 대검'], '싸움꾼']
# ['5', ['3여신의 눈물', '3쓸데없이 큰 지팡이', '2음전자 망토', '2연습용 장갑', '2쇠사슬 조끼', '2거인의 허리띠', '2B.F. 대검', '1곡궁'], '선봉대신비술사']
# ['1', ['6곡궁', '4여신의 눈물', '3B.F. 대검', '2음전자 망토', '1연습용 장갑', '1쓸데없이 큰 지팡이', '1거인의 허리띠'], '신성조율자']
# ['1', ['5여신의 눈물', '3음전자 망토', '2연습용 장갑', '2곡궁', '2거인의 허리띠', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1뒤집개', '1B.F. 대검'], '나무정령요술사']
# ['1', ['5음전자 망토', '4곡궁', '3쓸데없이 큰 지팡이', '2B.F. 대검', '1쇠사슬 조끼', '1거인의 허리띠'], '나무정령싸움꾼']
# ['1', ['4여신의 눈물', '4쓸데없이 큰 지팡이', '4쇠사슬 조끼', '3B.F. 대검', '2거인의 허리띠', '1음전자 망토', '1연습용 장갑', '1곡궁'], '황혼']
# ['3', ['5여신의 눈물', '3음전자 망토', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2뒤집개', '1곡궁', '1거인의 허리띠', '1B.F. 대검'], '나무정령요술사']
# ['3', ['4쓸데없이 큰 지팡이', '4쇠사슬 조끼', '2곡궁', '2거인의 허리띠', '1음전자 망토', '1연습용 장갑', '1B.F. 대검'], '황혼']
# ['6', ['3곡궁', '2음전자 망토', '2연습용 장갑', '2여신의 눈물', '2거인의 허리띠', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1뒤집개', '1B.F. 대검'], '나무정령요술사']
# ['4', ['5쓸데없이 큰 지팡이', '4B.F. 대검', '3곡궁', '2음전자 망토', '2연습용 장갑', '2쇠사슬 조끼', '1거인의 허리띠'], '명사수귀감']
# ['2', ['4거인의 허리띠', '3쇠사슬 조끼', '2곡궁', '2B.F. 대검', '1음전자 망토', '1연습용 장갑', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1뒤집개'], '나무정령요술사']
# ['7', ['3여신의 눈물', '3쓸데없이 큰 지팡이', '3B.F. 대검', '2연습용 장갑', '1쇠사슬 조끼', '1곡궁', '1거인의 허리띠'], '달빛사냥꾼']
# ['4', ['5B.F. 대검', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2곡궁', '1음전자 망토', '1여신의 눈물', '1뒤집개'], '명사수귀감']
# ['4', ['5곡궁', '4쇠사슬 조끼', '4거인의 허리띠', '3여신의 눈물', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2B.F. 대검'], '싸움꾼']
# ['2', ['6B.F. 대검', '4거인의 허리띠', '3쓸데없이 큰 지팡이', '2음전자 망토', '2여신의 눈물', '2쇠사슬 조끼', '2곡궁'], '명사수귀감']
# ['3', ['4거인의 허리띠', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2곡궁', '1음전자 망토', '1여신의 눈물'], '싸움꾼']
# ['2', ['3음전자 망토', '3여신의 눈물', '3곡궁', '3B.F. 대검', '2쇠사슬 조끼', '2거인의 허리띠', '1쓸데없이 큰 지팡이', '1뒤집개'], '신성조율자']
# ['1', ['4여신의 눈물', '4쇠사슬 조끼', '4B.F. 대검', '3거인의 허리띠', '2음전자 망토', '2연습용 장갑', '2뒤집개', '2곡궁', '1쓸데없이 큰 지팡이'], '나무정령요술사']
# ['2', ['4거인의 허리띠', '4B.F. 대검', '3쇠사슬 조끼', '2음전자 망토', '2곡궁', '1연습용 장갑', '1여신의 눈물', '1쓸데없이 큰 지팡이'], '명사수귀감']
# ['1', ['4여신의 눈물', '3연습용 장갑', '3쓸데없이 큰 지팡이', '3쇠사슬 조끼', '3곡궁', '2뒤집개', '1음전자 망토', '1거인의 허리띠', '1B.F. 대검'], '나무정령요술사']
# ['7', ['3여신의 눈물', '3B.F. 대검', '2연습용 장갑', '2곡궁', '1음전자 망토', '1뒤집개', '1거인의 허리띠'], '나무정령요술사']
# ['1', ['4여신의 눈물', '4곡궁', '3쇠사슬 조끼', '2연습용 장갑', '1음전자 망토', '1쓸데없이 큰 지팡이', '1거인의 허리띠', '1B.F. 대검'], '나무정령요술사']
# ['7', ['3음전자 망토', '2연습용 장갑', '2여신의 눈물', '2쇠사슬 조끼', '2거인의 허리띠', '2B.F. 대검', '1곡궁'], '선봉대신비술사']
# ['1', ['4여신의 눈물', '4B.F. 대검', '3음전자 망토', '3쇠사슬 조끼', '2쓸데없이 큰 지팡이', '1연습용 장갑', '1뒤집개', '1곡궁', '1거인의 허리띠'], '나무정령요술사']
# ['7', ['4쓸데없이 큰 지팡이', '3연습용 장갑', '3쇠사슬 조끼', '2여신의 눈물', '2곡궁', '1음전자 망토', '1뒤집개', '1거인의 허리띠', '1B.F. 대검'], '황혼']
# ['3', ['4여신의 눈물', '3쇠사슬 조끼', '3곡궁', '3거인의 허리띠', '2연습용 장갑', '2쓸데없이 큰 지팡이', '1음전자 망토', '1B.F. 대검'], '결투가']
# ['3', ['4곡궁', '3음전자 망토', '3여신의 눈물', '3쓸데없이 큰 지팡이', '3B.F. 대검', '1쇠사슬 조끼', '1거인의 허리띠'], '신성조율자']
# ['4', ['4연습용 장갑', '3쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2곡궁', '2거인의 허리띠', '1음전자 망토', '1여신의 눈물', '1B.F. 대검'], '달빛사냥꾼']
# ['2', ['4쇠사슬 조끼', '3음전자 망토', '3거인의 허리띠', '1연습용 장갑', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1뒤집개', '1곡궁', '1B.F. 대검'], '황혼']
# ['6', ['2여신의 눈물', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2거인의 허리띠', '2B.F. 대검', '1연습용 장갑', '1곡궁'], '달빛사냥꾼']
# ['3', ['3연습용 장갑', '3쓸데없이 큰 지팡이', '2음전자 망토', '2여신의 눈물', '2쇠사슬 조끼', '2거인의 허리띠', '1뒤집개', '1B.F. 대검'], '선봉대신비술사']
# ['6', ['4곡궁', '2음전자 망토', '2연습용 장갑', '2쇠사슬 조끼', '2거인의 허리띠', '2B.F. 대검', '1여신의 눈물', '1쓸데없이 큰 지팡이'], '명사수귀감']
# ['6', ['3음전자 망토', '2연습용 장갑', '2여신의 눈물', '2쇠사슬 조끼', '2곡궁', '2거인의 허리띠', '2B.F. 대검', '1쓸데없이 큰 지팡이'], '선봉대신비술사']
# ['5', ['3연습용 장갑', '3곡궁', '2음전자 망토', '2쇠사슬 조끼', '2거인의 허리띠', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1뒤집개', '1B.F. 대검'], '명사수귀감']
# ['2', ['4쇠사슬 조끼', '4곡궁', '3여신의 눈물', '2연습용 장갑', '2거인의 허리띠', '2B.F. 대검', '1음전자 망토'], '결투가']
# ['1', ['8거인의 허리띠', '3여신의 눈물', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2곡궁', '1B.F. 대검'], '싸움꾼']
# ['2', ['3음전자 망토', '3연습용 장갑', '3쓸데없이 큰 지팡이', '3쇠사슬 조끼', '3곡궁', '2거인의 허리띠', '1B.F. 대검'], '황혼']
# ['2', ['5음전자 망토', '3쇠사슬 조끼', '3곡궁', '2B.F. 대검', '1연습용 장갑', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1뒤집개', '1거인의 허리띠'], '신성조율자']
# ['5', ['4쓸데없이 큰 지팡이', '4쇠사슬 조끼', '2음전자 망토', '2연습용 장갑', '2B.F. 대검', '1여신의 눈물', '1곡궁'], '황혼']
# ['1', ['4여신의 눈물', '4쇠사슬 조끼', '4B.F. 대검', '3음전자 망토', '2연습용 장갑', '1쓸데없이 큰 지팡이', '1곡궁', '1거인의 허리띠'], '조율자결투가']
# ['3', ['4곡궁', '4거인의 허리띠', '3연습용 장갑', '3쓸데없이 큰 지팡이', '2여신의 눈물', '2쇠사슬 조끼', '2B.F. 대검', '1음전자 망토'], '달빛사냥꾼']
# ['3', ['5쇠사슬 조끼', '2음전자 망토', '2여신의 눈물', '2곡궁', '2거인의 허리띠', '2B.F. 대검', '1연습용 장갑', '1쓸데없이 큰 지팡이'], '신성조율자']
# ['3', ['4쇠사슬 조끼', '4B.F. 대검', '3음전자 망토', '2연습용 장갑', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1뒤집개', '1곡궁', '1거인의 허리띠'], '황혼']
# ['3', ['3음전자 망토', '3쓸데없이 큰 지팡이', '3거인의 허리띠', '3B.F. 대검', '2여신의 눈물', '1연습용 장갑', '1쇠사슬 조끼', '1뒤집개', '1곡궁'], '선봉대신비술사']
# ['2', ['5음전자 망토', '5곡궁', '4거인의 허리띠', '3여신의 눈물', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2뒤집개', '1쇠사슬 조끼', '1B.F. 대검'], '나무정령요술사']
# ['3', ['5B.F. 대검', '4음전자 망토', '3쓸데없이 큰 지팡이', '3쇠사슬 조끼', '3거인의 허리띠', '2여신의 눈물', '2곡궁', '1연습용 장갑'], '광신도']
# ['1', ['5거인의 허리띠', '2음전자 망토', '2연습용 장갑', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2B.F. 대검', '1쇠사슬 조끼', '1뒤집개', '1곡궁'], '달빛사냥꾼']
# ['2', ['4쇠사슬 조끼', '3음전자 망토', '3연습용 장갑', '3B.F. 대검', '2쓸데없이 큰 지팡이', '2곡궁', '2거인의 허리띠', '1여신의 눈물'], '황혼']
# ['3', ['5거인의 허리띠', '4곡궁', '3음전자 망토', '3쓸데없이 큰 지팡이', '3B.F. 대검', '2연습용 장갑', '2여신의 눈물'], '선봉대신비술사']
# ['1', ['4곡궁', '3음전자 망토', '3연습용 장갑', '3B.F. 대검', '2여신의 눈물', '2거인의 허리띠', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼'], '달빛사냥꾼']
# ['1', ['4거인의 허리띠', '4B.F. 대검', '3여신의 눈물', '3쓸데없이 큰 지팡이', '2음전자 망토', '2연습용 장갑', '2곡궁', '1쇠사슬 조끼'], '달빛사냥꾼']
# ['3', ['4곡궁', '3음전자 망토', '2여신의 눈물', '2쇠사슬 조끼', '2B.F. 대검', '1연습용 장갑', '1쓸데없이 큰 지팡이', '1거인의 허리띠'], '신성조율자']
# ['2', ['5거인의 허리띠', '3쓸데없이 큰 지팡이', '3B.F. 대검', '2음전자 망토', '2쇠사슬 조끼', '2곡궁', '1연습용 장갑', '1여신의 눈물'], '황혼']
# ['7', ['4음전자 망토', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2곡궁', '2B.F. 대검', '1여신의 눈물', '1거인의 허리띠'], '명사수귀감']
# ['2', ['4곡궁', '4B.F. 대검', '3쓸데없이 큰 지팡이', '3거인의 허리띠', '2연습용 장갑', '2쇠사슬 조끼', '1음전자 망토'], '명사수귀감']
# ['1', ['5음전자 망토', '3여신의 눈물', '3쓸데없이 큰 지팡이', '3거인의 허리띠', '3B.F. 대검', '2곡궁', '1연습용 장갑', '1쇠사슬 조끼'], '선봉대신비술사']
# ['1', ['3쓸데없이 큰 지팡이', '3쇠사슬 조끼', '3B.F. 대검', '2음전자 망토', '2연습용 장갑', '2곡궁', '2거인의 허리띠', '1여신의 눈물'], '황혼']
# ['2', ['6쓸데없이 큰 지팡이', '3음전자 망토', '2연습용 장갑', '2여신의 눈물', '2B.F. 대검', '1곡궁'], '선봉대신비술사']
# ['2', ['6연습용 장갑', '4쇠사슬 조끼', '3음전자 망토', '3여신의 눈물', '3쓸데없이 큰 지팡이', '2거인의 허리띠', '1뒤집개', '1곡궁', '1B.F. 대검'], '선봉대신비술사']
# ['1', ['4B.F. 대검', '3여신의 눈물', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2뒤집개', '2거인의 허리띠', '1음전자 망토', '1쇠사슬 조끼', '1곡궁'], '달빛사냥꾼']
# ['7', ['3음전자 망토', '3여신의 눈물', '3쇠사슬 조끼', '2쓸데없이 큰 지팡이', '2거인의 허리띠', '1연습용 장갑', '1곡궁'], '선봉대신비술사']
# ['4', ['6음전자 망토', '4쇠사슬 조끼', '3B.F. 대검', '2거인의 허리띠', '1연습용 장갑', '1쓸데없이 큰 지팡이', '1곡궁'], '광신도']
# ['6', ['3음전자 망토', '3거인의 허리띠', '2연습용 장갑', '2쇠사슬 조끼', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1곡궁', '1B.F. 대검'], '선봉대신비술사']
# ['4', ['5쓸데없이 큰 지팡이', '4음전자 망토', '2여신의 눈물', '2쇠사슬 조끼', '2B.F. 대검', '1곡궁'], '선봉대신비술사']
# ['2', ['5곡궁', '4여신의 눈물', '3쓸데없이 큰 지팡이', '3쇠사슬 조끼', '3B.F. 대검', '2음전자 망토', '1연습용 장갑'], '신성조율자']
# ['2', ['4B.F. 대검', '3음전자 망토', '3곡궁', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2뒤집개', '1연습용 장갑', '1거인의 허리띠'], '명사수귀감']
# ['2', ['4거인의 허리띠', '2음전자 망토', '2연습용 장갑', '2여신의 눈물', '2뒤집개', '2곡궁', '2B.F. 대검', '1쓸데없이 큰 지팡이'], '달빛사냥꾼']
# ['5', ['5B.F. 대검', '2음전자 망토', '2곡궁', '2거인의 허리띠', '1여신의 눈물', '1쇠사슬 조끼', '1뒤집개'], '그림자닌자']
# ['4', ['6곡궁', '4B.F. 대검', '3쓸데없이 큰 지팡이', '3쇠사슬 조끼', '3거인의 허리띠', '2연습용 장갑', '1음전자 망토', '1여신의 눈물'], '황혼']
# ['2', ['6음전자 망토', '3곡궁', '3B.F. 대검', '2연습용 장갑', '2여신의 눈물', '2뒤집개', '1거인의 허리띠'], '나무정령싸움꾼']
# ['4', ['4쇠사슬 조끼', '3B.F. 대검', '2음전자 망토', '2쓸데없이 큰 지팡이', '1연습용 장갑', '1여신의 눈물', '1뒤집개', '1곡궁', '1거인의 허리띠'], '황혼']
# ['1', ['4쇠사슬 조끼', '4거인의 허리띠', '3음전자 망토', '3곡궁', '2쓸데없이 큰 지팡이', '2B.F. 대검', '1연습용 장갑', '1여신의 눈물'], '싸움꾼']
# ['4', ['4곡궁', '3쇠사슬 조끼', '2음전자 망토', '2연습용 장갑', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2거인의 허리띠', '1B.F. 대검'], '황혼']
# ['1', ['4쓸데없이 큰 지팡이', '4B.F. 대검', '3음전자 망토', '3거인의 허리띠', '2연습용 장갑', '2곡궁', '1여신의 눈물', '1쇠사슬 조끼'], '명사수귀감']
# ['1', ['5B.F. 대검', '3여신의 눈물', '3쇠사슬 조끼', '3곡궁', '3거인의 허리띠', '2연습용 장갑', '1쓸데없이 큰 지팡이'], '나무정령요술사']
# ['3', ['4거인의 허리띠', '3쓸데없이 큰 지팡이', '2음전자 망토', '2여신의 눈물', '2쇠사슬 조끼', '2곡궁', '1연습용 장갑', '1뒤집개', '1B.F. 대검'], '나무정령싸움꾼']
# ['2', ['4여신의 눈물', '4쓸데없이 큰 지팡이', '4거인의 허리띠', '3곡궁', '2연습용 장갑', '2쇠사슬 조끼', '1음전자 망토'], '싸움꾼']
# ['5', ['4연습용 장갑', '2여신의 눈물', '2쇠사슬 조끼', '2곡궁', '2B.F. 대검', '1쓸데없이 큰 지팡이', '1거인의 허리띠'], '달빛사냥꾼']
# ['2', ['5곡궁', '3연습용 장갑', '3뒤집개', '3거인의 허리띠', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2B.F. 대검', '1음전자 망토', '1여신의 눈물'], '달빛사냥꾼']
# ['5', ['4음전자 망토', '3여신의 눈물', '3곡궁', '2쇠사슬 조끼', '2B.F. 대검', '1연습용 장갑', '1거인의 허리띠'], '신성조율자']
# ['2', ['4쓸데없이 큰 지팡이', '3여신의 눈물', '3쇠사슬 조끼', '2음전자 망토', '2연습용 장갑', '2B.F. 대검', '1곡궁', '1거인의 허리띠'], '황혼']
# ['3', ['4연습용 장갑', '3여신의 눈물', '3곡궁', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2거인의 허리띠', '1B.F. 대검'], '싸움꾼']
# ['5', ['4여신의 눈물', '3거인의 허리띠', '2음전자 망토', '2B.F. 대검', '1연습용 장갑', '1쇠사슬 조끼', '1뒤집개', '1곡궁'], '나무정령요술사']
# ['1', ['4쇠사슬 조끼', '3곡궁', '3거인의 허리띠', '2음전자 망토', '2연습용 장갑', '2여신의 눈물', '2쓸데없이 큰 지팡이'], '싸움꾼']
# ['4', ['4연습용 장갑', '4쇠사슬 조끼', '3B.F. 대검', '2음전자 망토', '2여신의 눈물', '2곡궁', '1쓸데없이 큰 지팡이', '1거인의 허리띠'], '황혼']
# ['1', ['4곡궁', '3여신의 눈물', '2음전자 망토', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2거인의 허리띠', '1뒤집개', '1B.F. 대검'], '나무정령요술사']
# ['2', ['4음전자 망토', '4B.F. 대검', '3여신의 눈물', '3쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2거인의 허리띠', '1연습용 장갑', '1뒤집개', '1곡궁'], '광신도']
# ['1', ['6여신의 눈물', '6쓸데없이 큰 지팡이', '6거인의 허리띠', '5연습용 장갑', '3곡궁', '1음전자 망토', '1쇠사슬 조끼', '1뒤집개', '1B.F. 대검'], '싸움꾼']
# ['1', ['5곡궁', '5거인의 허리띠', '5B.F. 대검', '2음전자 망토', '2연습용 장갑', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼'], '그림자닌자']
# ['2', ['7거인의 허리띠', '3연습용 장갑', '2음전자 망토', '2여신의 눈물', '2쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1B.F. 대검'], '달빛사냥꾼']
# ['6', ['3음전자 망토', '3쇠사슬 조끼', '3곡궁', '2쓸데없이 큰 지팡이', '1여신의 눈물', '1뒤집개', '1거인의 허리띠'], '황혼']
# ['1', ['5여신의 눈물', '3연습용 장갑', '3쇠사슬 조끼', '2쓸데없이 큰 지팡이', '2거인의 허리띠', '1음전자 망토', '1곡궁', '1B.F. 대검'], '달빛사냥꾼']
# ['5', ['6음전자 망토', '3곡궁', '2연습용 장갑', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2거인의 허리띠', '2B.F. 대검', '1쇠사슬 조끼', '1뒤집개'], '선봉대신비술사']
# ['7', ['4쓸데없이 큰 지팡이', '4B.F. 대검', '3여신의 눈물', '3거인의 허리띠', '2음전자 망토', '2연습용 장갑'], '달빛사냥꾼']
# ['3', ['5곡궁', '4연습용 장갑', '4B.F. 대검', '3쓸데없이 큰 지팡이', '2여신의 눈물', '2쇠사슬 조끼', '2거인의 허리띠', '1음전자 망토'], '달빛사냥꾼']
# ['1', ['5연습용 장갑', '4쓸데없이 큰 지팡이', '3쇠사슬 조끼', '2음전자 망토', '2곡궁', '2B.F. 대검', '1여신의 눈물', '1뒤집개'], '황혼']
# ['4', ['3거인의 허리띠', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2곡궁', '2B.F. 대검', '1음전자 망토', '1연습용 장갑', '1뒤집개'], '달빛사냥꾼']
# ['1', ['4여신의 눈물', '4쇠사슬 조끼', '3쓸데없이 큰 지팡이', '2음전자 망토', '2곡궁', '2거인의 허리띠', '2B.F. 대검', '1연습용 장갑'], '나무정령요술사']
# ['5', ['5쇠사슬 조끼', '4여신의 눈물', '3연습용 장갑', '3쓸데없이 큰 지팡이', '2곡궁', '1음전자 망토', '1거인의 허리띠', '1B.F. 대검'], '나무정령요술사']
# ['2', ['4연습용 장갑', '4여신의 눈물', '4B.F. 대검', '3거인의 허리띠', '2쇠사슬 조끼', '2곡궁', '1음전자 망토', '1쓸데없이 큰 지팡이', '1뒤집개'], '결투가']
# ['7', ['4쇠사슬 조끼', '2여신의 눈물', '2거인의 허리띠', '1음전자 망토', '1연습용 장갑', '1곡궁', '1B.F. 대검'], '나무정령요술사']
# ['5', ['3쓸데없이 큰 지팡이', '3쇠사슬 조끼', '3B.F. 대검', '2여신의 눈물', '1음전자 망토', '1연습용 장갑', '1뒤집개', '1곡궁', '1거인의 허리띠'], '황혼']
# ['1', ['5음전자 망토', '4쇠사슬 조끼', '3여신의 눈물', '2연습용 장갑', '2쓸데없이 큰 지팡이', '1곡궁', '1거인의 허리띠'], '나무정령요술사']
# ['6', ['4B.F. 대검', '2연습용 장갑', '2여신의 눈물', '2쇠사슬 조끼', '2거인의 허리띠', '1음전자 망토', '1쓸데없이 큰 지팡이', '1뒤집개', '1곡궁'], '나무정령요술사']
# ['2', ['3B.F. 대검', '2음전자 망토', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2곡궁', '2거인의 허리띠', '1연습용 장갑'], '명사수귀감']
# ['2', ['3연습용 장갑', '3여신의 눈물', '3쇠사슬 조끼', '3거인의 허리띠', '3B.F. 대검', '2음전자 망토', '2쓸데없이 큰 지팡이', '2곡궁'], '달빛사냥꾼']
# ['3', ['4B.F. 대검', '3쇠사슬 조끼', '3곡궁', '2음전자 망토', '2거인의 허리띠', '1연습용 장갑', '1쓸데없이 큰 지팡이'], '명사수귀감']
# ['1', ['5음전자 망토', '4쇠사슬 조끼', '3곡궁', '2쓸데없이 큰 지팡이', '2뒤집개', '2거인의 허리띠', '1연습용 장갑', '1B.F. 대검'], '광신도']
# ['4', ['4연습용 장갑', '4거인의 허리띠', '3음전자 망토', '2쓸데없이 큰 지팡이', '1여신의 눈물', '1쇠사슬 조끼', '1뒤집개', '1곡궁'], '달빛사냥꾼']
# ['2', ['5쇠사슬 조끼', '3거인의 허리띠', '3B.F. 대검', '2연습용 장갑', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2곡궁', '1음전자 망토'], '달빛사냥꾼']
# ['2', ['4연습용 장갑', '3쇠사슬 조끼', '3거인의 허리띠', '2쓸데없이 큰 지팡이', '2B.F. 대검', '1여신의 눈물', '1곡궁'], '달빛사냥꾼']
# ['3', ['4B.F. 대검', '3여신의 눈물', '3쓸데없이 큰 지팡이', '2곡궁', '2거인의 허리띠', '1음전자 망토', '1쇠사슬 조끼'], '달빛사냥꾼']
# ['3', ['2연습용 장갑', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2곡궁', '2거인의 허리띠', '2B.F. 대검', '1음전자 망토', '1뒤집개'], '결투가']
# ['2', ['5연습용 장갑', '4쓸데없이 큰 지팡이', '4B.F. 대검', '3여신의 눈물', '3쇠사슬 조끼', '3거인의 허리띠', '2곡궁', '1음전자 망토'], '달빛사냥꾼']
# ['7', ['3쇠사슬 조끼', '3곡궁', '2거인의 허리띠', '2B.F. 대검', '1연습용 장갑', '1쓸데없이 큰 지팡이'], '신성조율자']
# ['4', ['4연습용 장갑', '4여신의 눈물', '2음전자 망토', '2쇠사슬 조끼', '1쓸데없이 큰 지팡이', '1곡궁', '1B.F. 대검'], '조율자결투가']
# ['2', ['6쇠사슬 조끼', '3음전자 망토', '3곡궁', '3B.F. 대검', '2쓸데없이 큰 지팡이', '2거인의 허리띠', '1연습용 장갑', '1뒤집개'], '광신도']
# ['2', ['4곡궁', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2뒤집개', '2거인의 허리띠', '2B.F. 대검', '1음전자 망토', '1연습용 장갑'], '신성조율자']
# ['3', ['4연습용 장갑', '4쇠사슬 조끼', '3쓸데없이 큰 지팡이', '2음전자 망토', '2여신의 눈물', '1뒤집개', '1거인의 허리띠'], '황혼']
# ['1', ['4음전자 망토', '4여신의 눈물', '3쓸데없이 큰 지팡이', '3곡궁', '2거인의 허리띠', '2B.F. 대검', '1연습용 장갑', '1쇠사슬 조끼'], '선봉대신비술사']
# ['7', ['4B.F. 대검', '3연습용 장갑', '2음전자 망토', '2뒤집개', '2곡궁', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼'], '명사수귀감']
# ['3', ['4곡궁', '3음전자 망토', '3쇠사슬 조끼', '2쓸데없이 큰 지팡이', '2B.F. 대검', '1연습용 장갑', '1여신의 눈물'], '황혼']
# ['5', ['3곡궁', '3B.F. 대검', '2연습용 장갑', '2거인의 허리띠', '1음전자 망토', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼'], '그림자닌자']
# ['1', ['5음전자 망토', '3뒤집개', '3거인의 허리띠', '3B.F. 대검', '2곡궁', '1연습용 장갑', '1쇠사슬 조끼'], '광신도']
# ['3', ['6B.F. 대검', '4연습용 장갑', '3곡궁', '2여신의 눈물', '2쇠사슬 조끼', '1음전자 망토', '1뒤집개', '1거인의 허리띠'], '명사수귀감']
# ['2', ['5음전자 망토', '3연습용 장갑', '3B.F. 대검', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2뒤집개', '1여신의 눈물', '1곡궁', '1거인의 허리띠'], '황혼']
# ['6', ['3연습용 장갑', '3곡궁', '3거인의 허리띠', '3B.F. 대검', '2쓸데없이 큰 지팡이', '1여신의 눈물', '1쇠사슬 조끼', '1뒤집개'], '달빛사냥꾼']
# ['3', ['4거인의 허리띠', '3쓸데없이 큰 지팡이', '2음전자 망토', '2여신의 눈물', '2쇠사슬 조끼', '1연습용 장갑', '1뒤집개', '1곡궁', '1B.F. 대검'], '선봉대신비술사']
# ['4', ['4B.F. 대검', '3음전자 망토', '3여신의 눈물', '3쓸데없이 큰 지팡이', '3쇠사슬 조끼', '3거인의 허리띠', '2연습용 장갑'], '황혼']
# ['1', ['3여신의 눈물', '3뒤집개', '3거인의 허리띠', '2음전자 망토', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '1연습용 장갑', '1곡궁', '1B.F. 대검'], '나무정령요술사']
# ['2', ['4곡궁', '4B.F. 대검', '2음전자 망토', '2연습용 장갑', '2여신의 눈물', '2거인의 허리띠', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼'], '그림자닌자']
# ['4', ['5쇠사슬 조끼', '3쓸데없이 큰 지팡이', '2여신의 눈물', '2곡궁', '2거인의 허리띠', '1음전자 망토', '1연습용 장갑', '1뒤집개'], '황혼']
# ['3', ['5B.F. 대검', '2음전자 망토', '2연습용 장갑', '2여신의 눈물', '2쇠사슬 조끼', '2뒤집개', '2거인의 허리띠', '1쓸데없이 큰 지팡이', '1곡궁'], '명사수귀감']
# ['5', ['5음전자 망토', '4쓸데없이 큰 지팡이', '4쇠사슬 조끼', '4B.F. 대검', '3곡궁'], '광신도']
# ['2', ['5쇠사슬 조끼', '4쓸데없이 큰 지팡이', '2음전자 망토', '2거인의 허리띠', '2B.F. 대검', '1여신의 눈물', '1뒤집개', '1곡궁'], '황혼']
# ['7', ['5곡궁', '2음전자 망토', '1연습용 장갑', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1뒤집개', '1B.F. 대검'], '나무정령싸움꾼']
# ['5', ['3여신의 눈물', '2음전자 망토', '2쓸데없이 큰 지팡이', '2뒤집개', '2곡궁', '2B.F. 대검', '1연습용 장갑', '1쇠사슬 조끼', '1거인의 허리띠'], '나무정령요술사']
# ['6', ['3여신의 눈물', '3곡궁', '2음전자 망토', '2쇠사슬 조끼', '1연습용 장갑', '1쓸데없이 큰 지팡이', '1거인의 허리띠', '1B.F. 대검'], '신성조율자']
# ['1', ['4거인의 허리띠', '3여신의 눈물', '3쇠사슬 조끼', '3B.F. 대검', '2연습용 장갑', '2쓸데없이 큰 지팡이', '1곡궁'], '달빛사냥꾼']
# ['4', ['4연습용 장갑', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2뒤집개', '2거인의 허리띠', '1음전자 망토', '1여신의 눈물', '1곡궁', '1B.F. 대검'], '달빛사냥꾼']
# ['6', ['4음전자 망토', '4거인의 허리띠', '3여신의 눈물', '3B.F. 대검', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2곡궁'], '신성조율자']
# ['6', ['3곡궁', '2음전자 망토', '2연습용 장갑', '2쇠사슬 조끼', '2B.F. 대검', '1여신의 눈물', '1쓸데없이 큰 지팡이'], '명사수귀감']
# ['2', ['5여신의 눈물', '5쓸데없이 큰 지팡이', '5곡궁', '3음전자 망토', '3연습용 장갑', '2거인의 허리띠', '1쇠사슬 조끼', '1B.F. 대검'], '선봉대신비술사']
# ['4', ['4곡궁', '3쓸데없이 큰 지팡이', '3쇠사슬 조끼', '3B.F. 대검', '2음전자 망토', '1연습용 장갑', '1여신의 눈물', '1거인의 허리띠'], '황혼']
# ['2', ['4음전자 망토', '4여신의 눈물', '4쓸데없이 큰 지팡이', '3곡궁', '2연습용 장갑', '2쇠사슬 조끼', '2거인의 허리띠', '2B.F. 대검', '1뒤집개'], '나무정령요술사']
# ['5', ['4여신의 눈물', '3연습용 장갑', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2곡궁', '2거인의 허리띠', '1음전자 망토', '1뒤집개', '1B.F. 대검'], '결투가']
# ['1', ['5여신의 눈물', '3쇠사슬 조끼', '3거인의 허리띠', '2곡궁', '1음전자 망토', '1연습용 장갑', '1쓸데없이 큰 지팡이', '1뒤집개', '1B.F. 대검'], '결투가']
# ['1', ['4쓸데없이 큰 지팡이', '4곡궁', '3뒤집개', '3B.F. 대검', '2연습용 장갑', '2거인의 허리띠', '1여신의 눈물', '1쇠사슬 조끼'], '나무정령싸움꾼']
# ['4', ['4연습용 장갑', '3쓸데없이 큰 지팡이', '2음전자 망토', '2쇠사슬 조끼', '1여신의 눈물', '1뒤집개', '1곡궁', '1거인의 허리띠', '1B.F. 대검'], '황혼']
# ['6', ['3음전자 망토', '3연습용 장갑', '3곡궁', '3거인의 허리띠', '3B.F. 대검', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼'], '그림자닌자']
# ['7', ['3음전자 망토', '3거인의 허리띠', '2쇠사슬 조끼', '2곡궁', '2B.F. 대검', '1연습용 장갑', '1쓸데없이 큰 지팡이'], '광신도']
# ['6', ['3쇠사슬 조끼', '3거인의 허리띠', '3B.F. 대검', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2곡궁', '1연습용 장갑'], '달빛사냥꾼']
# ['2', ['3쇠사슬 조끼', '3곡궁', '2연습용 장갑', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2거인의 허리띠', '1음전자 망토', '1뒤집개', '1B.F. 대검'], '나무정령요술사']
# ['5', ['4여신의 눈물', '3쓸데없이 큰 지팡이', '3곡궁', '2음전자 망토', '1쇠사슬 조끼', '1뒤집개', '1거인의 허리띠', '1B.F. 대검'], '나무정령요술사']
# ['1', ['4거인의 허리띠', '3연습용 장갑', '3쇠사슬 조끼', '3곡궁', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2B.F. 대검', '1음전자 망토', '1뒤집개'], '달빛사냥꾼']
# ['1', ['4여신의 눈물', '4곡궁', '3음전자 망토', '3거인의 허리띠', '2연습용 장갑', '2뒤집개', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1B.F. 대검'], '나무정령요술사']
# ['3', ['4거인의 허리띠', '3연습용 장갑', '3쓸데없이 큰 지팡이', '2음전자 망토', '2곡궁', '1여신의 눈물', '1쇠사슬 조끼', '1뒤집개', '1B.F. 대검'], '나무정령싸움꾼']
# ['2', ['4음전자 망토', '4여신의 눈물', '4뒤집개', '3쇠사슬 조끼', '3거인의 허리띠', '2연습용 장갑', '2B.F. 대검'], '결투가']
# ['2', ['4여신의 눈물', '3음전자 망토', '3쓸데없이 큰 지팡이', '3쇠사슬 조끼', '2뒤집개', '1연습용 장갑', '1곡궁', '1거인의 허리띠', '1B.F. 대검'], '나무정령요술사']
# ['5', ['3연습용 장갑', '3쓸데없이 큰 지팡이', '3B.F. 대검', '2뒤집개', '2곡궁', '1음전자 망토', '1여신의 눈물', '1거인의 허리띠'], '나무정령싸움꾼']
# ['2', ['4여신의 눈물', '4쓸데없이 큰 지팡이', '3쇠사슬 조끼', '2연습용 장갑', '2뒤집개', '2거인의 허리띠', '1음전자 망토', '1곡궁', '1B.F. 대검'], '나무정령요술사']
# ['8', ['3거인의 허리띠', '3B.F. 대검', '2쇠사슬 조끼', '1음전자 망토', '1연습용 장갑', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1뒤집개'], '달빛사냥꾼']
# ['5', ['4연습용 장갑', '4B.F. 대검', '3음전자 망토', '3곡궁', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2거인의 허리띠'], '명사수귀감']
# ['2', ['5쇠사슬 조끼', '4연습용 장갑', '4여신의 눈물', '2음전자 망토', '2곡궁', '1쓸데없이 큰 지팡이', '1거인의 허리띠', '1B.F. 대검'], '나무정령요술사']
# ['3', ['4여신의 눈물', '3쇠사슬 조끼', '2음전자 망토', '2거인의 허리띠', '1연습용 장갑', '1쓸데없이 큰 지팡이', '1뒤집개', '1곡궁', '1B.F. 대검'], '나무정령요술사']
# ['5', ['5쓸데없이 큰 지팡이', '2음전자 망토', '2쇠사슬 조끼', '2거인의 허리띠', '2B.F. 대검', '1연습용 장갑', '1뒤집개', '1곡궁'], '황혼']
# ['2', ['5여신의 눈물', '4연습용 장갑', '3쇠사슬 조끼', '2음전자 망토', '2뒤집개', '2곡궁', '2거인의 허리띠'], '결투가']
# ['1', ['3음전자 망토', '3연습용 장갑', '3B.F. 대검', '2쓸데없이 큰 지팡이', '2뒤집개', '2곡궁', '1여신의 눈물', '1쇠사슬 조끼', '1거인의 허리띠'], '나무정령싸움꾼']
# ['6', ['3여신의 눈물', '3곡궁', '3거인의 허리띠', '2음전자 망토', '2연습용 장갑', '1쓸데없이 큰 지팡이', '1B.F. 대검'], '신성조율자']
# ['2', ['7연습용 장갑', '5쓸데없이 큰 지팡이', '5거인의 허리띠', '5B.F. 대검', '4음전자 망토', '2여신의 눈물', '2쇠사슬 조끼', '2곡궁'], '달빛사냥꾼']
# ['4', ['4쓸데없이 큰 지팡이', '4쇠사슬 조끼', '4곡궁', '3음전자 망토', '2연습용 장갑', '1여신의 눈물'], '황혼']
# ['3', ['5곡궁', '3거인의 허리띠', '2연습용 장갑', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2B.F. 대검', '1음전자 망토'], '달빛사냥꾼']
# ['6', ['3연습용 장갑', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2곡궁', '1음전자 망토', '1거인의 허리띠', '1B.F. 대검'], '달빛사냥꾼']
# ['3', ['5곡궁', '4B.F. 대검', '3음전자 망토', '3연습용 장갑', '2뒤집개', '2거인의 허리띠', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼'], '그림자닌자']
# ['6', ['5연습용 장갑', '4쇠사슬 조끼', '4곡궁', '3음전자 망토', '3거인의 허리띠', '3B.F. 대검', '2여신의 눈물', '1쓸데없이 큰 지팡이'], '달빛사냥꾼']
# ['6', ['3연습용 장갑', '3쓸데없이 큰 지팡이', '2여신의 눈물', '2쇠사슬 조끼', '2거인의 허리띠', '1음전자 망토', '1곡궁', '1B.F. 대검'], '달빛사냥꾼']
# ['2', ['6연습용 장갑', '5B.F. 대검', '3쇠사슬 조끼', '2여신의 눈물', '2거인의 허리띠', '1음전자 망토', '1쓸데없이 큰 지팡이', '1곡궁'], '달빛사냥꾼']
# ['5', ['5쓸데없이 큰 지팡이', '4여신의 눈물', '4거인의 허리띠', '3음전자 망토', '2쇠사슬 조끼', '1연습용 장갑', '1B.F. 대검'], '선봉대신비술사']
# ['1', ['4음전자 망토', '4쓸데없이 큰 지팡이', '3연습용 장갑', '3여신의 눈물', '3곡궁', '2거인의 허리띠', '2B.F. 대검', '1쇠사슬 조끼'], '선봉대신비술사']
# ['3', ['5거인의 허리띠', '4B.F. 대검', '2음전자 망토', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '1연습용 장갑', '1곡궁'], '달빛사냥꾼']
# ['4', ['4연습용 장갑', '2여신의 눈물', '2곡궁', '2거인의 허리띠', '1음전자 망토', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1B.F. 대검'], '달빛사냥꾼']
# ['4', ['5거인의 허리띠', '3연습용 장갑', '3쇠사슬 조끼', '2쓸데없이 큰 지팡이', '1음전자 망토', '1뒤집개', '1B.F. 대검'], '싸움꾼']
# ['3', ['3음전자 망토', '3연습용 장갑', '2쇠사슬 조끼', '2곡궁', '2거인의 허리띠', '2B.F. 대검', '1여신의 눈물', '1쓸데없이 큰 지팡이'], '명사수귀감']
# ['3', ['4여신의 눈물', '3쇠사슬 조끼', '3곡궁', '2음전자 망토', '2쓸데없이 큰 지팡이', '1뒤집개', '1거인의 허리띠', '1B.F. 대검'], '나무정령요술사']
# ['8', ['3연습용 장갑', '2음전자 망토', '2여신의 눈물', '2곡궁', '1쓸데없이 큰 지팡이', '1거인의 허리띠', '1B.F. 대검'], '달빛사냥꾼']
# ['1', ['3음전자 망토', '3쇠사슬 조끼', '2연습용 장갑', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2뒤집개', '2B.F. 대검', '1곡궁', '1거인의 허리띠'], '나무정령요술사']
# ['3', ['3곡궁', '2연습용 장갑', '2여신의 눈물', '2쇠사슬 조끼', '2B.F. 대검', '1음전자 망토', '1쓸데없이 큰 지팡이', '1거인의 허리띠'], '신성조율자']
# ['6', ['3음전자 망토', '3여신의 눈물', '2연습용 장갑', '2B.F. 대검', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1곡궁', '1거인의 허리띠'], '나무정령요술사']
# ['3', ['4음전자 망토', '4여신의 눈물', '3쓸데없이 큰 지팡이', '2곡궁', '1연습용 장갑', '1쇠사슬 조끼', '1B.F. 대검'], '나무정령요술사']
# ['2', ['5음전자 망토', '3연습용 장갑', '2여신의 눈물', '2쇠사슬 조끼', '2뒤집개', '2곡궁', '2거인의 허리띠', '1쓸데없이 큰 지팡이', '1B.F. 대검'], '선봉대신비술사']
# ['4', ['5연습용 장갑', '4곡궁', '3여신의 눈물', '3쇠사슬 조끼', '1음전자 망토', '1뒤집개', '1거인의 허리띠'], '나무정령요술사']
# ['2', ['6쓸데없이 큰 지팡이', '3여신의 눈물', '3쇠사슬 조끼', '2연습용 장갑', '1음전자 망토', '1뒤집개', '1거인의 허리띠', '1B.F. 대검'], '나무정령요술사']
# ['3', ['4쓸데없이 큰 지팡이', '3거인의 허리띠', '2음전자 망토', '2연습용 장갑', '2쇠사슬 조끼', '2뒤집개', '2곡궁', '1B.F. 대검'], '나무정령싸움꾼']
# ['5', ['5연습용 장갑', '3쓸데없이 큰 지팡이', '3곡궁', '2거인의 허리띠', '2B.F. 대검'], '달빛사냥꾼']
# ['1', ['5B.F. 대검', '4곡궁', '3여신의 눈물', '2음전자 망토', '2연습용 장갑', '2쓸데없이 큰 지팡이', '1거인의 허리띠'], '명사수귀감']
# ['4', ['4여신의 눈물', '4쓸데없이 큰 지팡이', '4B.F. 대검', '2쇠사슬 조끼', '2곡궁'], '명사수귀감']
# ['2', ['5곡궁', '4쓸데없이 큰 지팡이', '2여신의 눈물', '2뒤집개', '1음전자 망토', '1연습용 장갑', '1쇠사슬 조끼', '1거인의 허리띠', '1B.F. 대검'], '나무정령싸움꾼']
# ['1', ['4쓸데없이 큰 지팡이', '4쇠사슬 조끼', '4B.F. 대검', '2음전자 망토', '2연습용 장갑', '2뒤집개', '1여신의 눈물', '1곡궁'], '황혼']
# ['1', ['4음전자 망토', '4곡궁', '3쇠사슬 조끼', '2연습용 장갑', '2거인의 허리띠', '2B.F. 대검', '1쓸데없이 큰 지팡이'], '광신도']
# ['6', ['3쇠사슬 조끼', '3곡궁', '3거인의 허리띠', '2연습용 장갑', '2B.F. 대검', '1음전자 망토', '1여신의 눈물', '1쓸데없이 큰 지팡이'], '그림자닌자']
# ['3', ['5쇠사슬 조끼', '3연습용 장갑', '3B.F. 대검', '2여신의 눈물', '2쓸데없이 큰 지팡이', '1음전자 망토', '1뒤집개', '1거인의 허리띠'], '나무정령요술사']
# ['6', ['3B.F. 대검', '2연습용 장갑', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2곡궁', '2거인의 허리띠', '1음전자 망토'], '달빛사냥꾼']
# ['7', ['3음전자 망토', '3곡궁', '2여신의 눈물', '2쓸데없이 큰 지팡이', '1연습용 장갑', '1쇠사슬 조끼', '1거인의 허리띠', '1B.F. 대검'], '선봉대신비술사']
# ['7', ['3음전자 망토', '2연습용 장갑', '2쇠사슬 조끼', '2곡궁', '2거인의 허리띠', '2B.F. 대검', '1쓸데없이 큰 지팡이'], '명사수귀감']
# ['2', ['4여신의 눈물', '3쓸데없이 큰 지팡이', '2음전자 망토', '2쇠사슬 조끼', '2곡궁', '2거인의 허리띠', '2B.F. 대검', '1연습용 장갑'], '나무정령요술사']
# ['8', ['4거인의 허리띠', '3곡궁', '2음전자 망토', '2쇠사슬 조끼', '2B.F. 대검', '1연습용 장갑', '1여신의 눈물'], '그림자닌자']
# ['5', ['4쇠사슬 조끼', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2거인의 허리띠', '2B.F. 대검', '1음전자 망토', '1여신의 눈물'], '황혼']
# ['2', ['4연습용 장갑', '4쓸데없이 큰 지팡이', '4쇠사슬 조끼', '3거인의 허리띠', '2여신의 눈물', '2B.F. 대검', '1음전자 망토', '1뒤집개', '1곡궁'], '달빛사냥꾼']
# ['2', ['4연습용 장갑', '4B.F. 대검', '3여신의 눈물', '3쇠사슬 조끼', '3곡궁', '2음전자 망토', '2쓸데없이 큰 지팡이', '1거인의 허리띠'], '명사수귀감']
# ['5', ['5곡궁', '4B.F. 대검', '3여신의 눈물', '3쇠사슬 조끼', '2음전자 망토', '2쓸데없이 큰 지팡이', '1거인의 허리띠'], '신성조율자']
# ['5', ['5연습용 장갑', '5곡궁', '4음전자 망토', '3쇠사슬 조끼', '3B.F. 대검', '2쓸데없이 큰 지팡이', '1여신의 눈물'], '황혼']
# ['3', ['4거인의 허리띠', '4B.F. 대검', '3음전자 망토', '3연습용 장갑', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '1여신의 눈물', '1곡궁'], '달빛사냥꾼']
# ['2', ['5음전자 망토', '4쇠사슬 조끼', '4B.F. 대검', '3쓸데없이 큰 지팡이', '3뒤집개', '2거인의 허리띠', '1연습용 장갑', '1여신의 눈물', '1곡궁'], '광신도']
# ['6', ['4거인의 허리띠', '3B.F. 대검', '2음전자 망토', '2쓸데없이 큰 지팡이', '1연습용 장갑', '1쇠사슬 조끼', '1곡궁'], '달빛사냥꾼']
# ['3', ['4B.F. 대검', '3음전자 망토', '3거인의 허리띠', '2여신의 눈물', '2쇠사슬 조끼', '2뒤집개', '2곡궁', '1쓸데없이 큰 지팡이'], '명사수귀감']
# ['1', ['5연습용 장갑', '5쇠사슬 조끼', '4음전자 망토', '3쓸데없이 큰 지팡이', '3곡궁', '2여신의 눈물', '2거인의 허리띠'], '선봉대신비술사']
# ['5', ['4여신의 눈물', '3쓸데없이 큰 지팡이', '3쇠사슬 조끼', '2거인의 허리띠', '1음전자 망토', '1연습용 장갑', '1곡궁', '1B.F. 대검'], '나무정령요술사']
# ['8', ['4여신의 눈물', '3연습용 장갑', '3B.F. 대검', '1음전자 망토', '1쓸데없이 큰 지팡이', '1곡궁'], '조율자결투가']
# ['2', ['6연습용 장갑', '5쓸데없이 큰 지팡이', '5거인의 허리띠', '3여신의 눈물', '2음전자 망토', '2쇠사슬 조끼', '2곡궁'], '싸움꾼']
# ['4', ['5쓸데없이 큰 지팡이', '3연습용 장갑', '3쇠사슬 조끼', '3B.F. 대검', '2음전자 망토', '2거인의 허리띠', '1여신의 눈물', '1곡궁'], '황혼']
# ['1', ['4여신의 눈물', '4쇠사슬 조끼', '3음전자 망토', '3연습용 장갑', '2뒤집개', '1쓸데없이 큰 지팡이', '1곡궁', '1거인의 허리띠', '1B.F. 대검'], '나무정령요술사']
# ['6', ['4연습용 장갑', '4거인의 허리띠', '3쓸데없이 큰 지팡이', '3B.F. 대검', '2쇠사슬 조끼', '1음전자 망토', '1여신의 눈물', '1곡궁'], '달빛사냥꾼']
# ['3', ['5여신의 눈물', '3연습용 장갑', '3쓸데없이 큰 지팡이', '3곡궁', '2쇠사슬 조끼', '2거인의 허리띠', '2B.F. 대검', '1음전자 망토', '1뒤집개'], '결투가']
# ['8', ['2음전자 망토', '2여신의 눈물', '1연습용 장갑', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1곡궁', '1거인의 허리띠', '1B.F. 대검'], '나무정령요술사']
# ['5', ['4여신의 눈물', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2곡궁', '1음전자 망토', '1뒤집개', '1거인의 허리띠', '1B.F. 대검'], '나무정령요술사']
# ['2', ['4쓸데없이 큰 지팡이', '3거인의 허리띠', '2음전자 망토', '2여신의 눈물', '2쇠사슬 조끼', '2곡궁', '2B.F. 대검', '1연습용 장갑'], '선봉대신비술사']
# ['3', ['4여신의 눈물', '3쇠사슬 조끼', '2음전자 망토', '2쓸데없이 큰 지팡이', '2거인의 허리띠', '1연습용 장갑', '1곡궁', '1B.F. 대검'], '나무정령요술사']
# ['5', ['5거인의 허리띠', '4연습용 장갑', '4B.F. 대검', '3음전자 망토', '2곡궁', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1뒤집개'], '그림자닌자']
# ['1', ['5쓸데없이 큰 지팡이', '3음전자 망토', '3쇠사슬 조끼', '3거인의 허리띠', '2연습용 장갑', '2여신의 눈물', '1곡궁', '1B.F. 대검'], '선봉대신비술사']
# ['4', ['5쓸데없이 큰 지팡이', '5곡궁', '4연습용 장갑', '4여신의 눈물', '4거인의 허리띠', '2쇠사슬 조끼', '1음전자 망토'], '싸움꾼']
# ['2', ['6여신의 눈물', '5음전자 망토', '3쓸데없이 큰 지팡이', '3곡궁', '3B.F. 대검', '2거인의 허리띠', '1쇠사슬 조끼', '1뒤집개'], '나무정령요술사']
# ['3', ['5B.F. 대검', '4곡궁', '3음전자 망토', '3연습용 장갑', '3거인의 허리띠', '1여신의 눈물', '1뒤집개'], '그림자닌자']
# ['7', ['4쇠사슬 조끼', '3B.F. 대검', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2곡궁', '1음전자 망토', '1여신의 눈물', '1거인의 허리띠'], '황혼']
# ['5', ['3쓸데없이 큰 지팡이', '3거인의 허리띠', '2음전자 망토', '2쇠사슬 조끼', '2곡궁', '1여신의 눈물', '1B.F. 대검'], '황혼']
# ['4', ['3여신의 눈물', '2음전자 망토', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2곡궁', '2거인의 허리띠', '1뒤집개'], '나무정령요술사']
# ['2', ['4음전자 망토', '3연습용 장갑', '3여신의 눈물', '3곡궁', '2거인의 허리띠', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1B.F. 대검'], '선봉대신비술사']
# ['3', ['5음전자 망토', '4B.F. 대검', '3여신의 눈물', '2쓸데없이 큰 지팡이', '2곡궁', '2거인의 허리띠', '1연습용 장갑', '1쇠사슬 조끼'], '광신도']
# ['3', ['2음전자 망토', '2연습용 장갑', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2곡궁', '2거인의 허리띠', '2B.F. 대검'], '명사수귀감']
# ['4', ['4곡궁', '3거인의 허리띠', '2연습용 장갑', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '1B.F. 대검'], '싸움꾼']
# ['1', ['4거인의 허리띠', '3연습용 장갑', '3쓸데없이 큰 지팡이', '3쇠사슬 조끼', '2여신의 눈물', '2B.F. 대검', '1음전자 망토', '1뒤집개', '1곡궁'], '달빛사냥꾼']
# ['4', ['3음전자 망토', '3여신의 눈물', '3쇠사슬 조끼', '2연습용 장갑', '2거인의 허리띠', '1쓸데없이 큰 지팡이', '1곡궁', '1B.F. 대검'], '나무정령요술사']
# ['4', ['4B.F. 대검', '3거인의 허리띠', '2연습용 장갑', '2여신의 눈물', '2쓸데없이 큰 지팡이', '1음전자 망토', '1쇠사슬 조끼', '1곡궁'], '달빛사냥꾼']
# ['8', ['3거인의 허리띠', '2쓸데없이 큰 지팡이', '2곡궁', '2B.F. 대검', '1음전자 망토', '1쇠사슬 조끼'], '달빛사냥꾼']
# ['3', ['3여신의 눈물', '3거인의 허리띠', '3B.F. 대검', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2곡궁', '1음전자 망토', '1쇠사슬 조끼'], '달빛사냥꾼']
# ['7', ['3연습용 장갑', '3쓸데없이 큰 지팡이', '2음전자 망토', '2거인의 허리띠', '1여신의 눈물', '1쇠사슬 조끼', '1곡궁', '1B.F. 대검'], '선봉대신비술사']
# ['5', ['3곡궁', '2음전자 망토', '2연습용 장갑', '2거인의 허리띠', '2B.F. 대검', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼'], '그림자닌자']
# ['8', ['2여신의 눈물', '2곡궁', '1음전자 망토', '1연습용 장갑', '1쇠사슬 조끼', '1거인의 허리띠', '1B.F. 대검'], '신성조율자']
# ['1', ['3쇠사슬 조끼', '3곡궁', '2음전자 망토', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2거인의 허리띠', '2B.F. 대검', '1여신의 눈물', '1뒤집개'], '황혼']
# ['3', ['5곡궁', '4쇠사슬 조끼', '3음전자 망토', '3연습용 장갑', '3B.F. 대검', '2쓸데없이 큰 지팡이', '2거인의 허리띠', '1여신의 눈물'], '황혼']
# ['2', ['5음전자 망토', '3곡궁', '3거인의 허리띠', '2쇠사슬 조끼', '2B.F. 대검', '1연습용 장갑', '1쓸데없이 큰 지팡이', '1뒤집개'], '광신도']
# ['2', ['4음전자 망토', '4여신의 눈물', '4쓸데없이 큰 지팡이', '4곡궁', '3쇠사슬 조끼', '2B.F. 대검', '1연습용 장갑', '1거인의 허리띠'], '신성조율자']
# ['4', ['4B.F. 대검', '3쇠사슬 조끼', '2연습용 장갑', '2여신의 눈물', '2거인의 허리띠', '1음전자 망토', '1쓸데없이 큰 지팡이', '1곡궁'], '나무정령요술사']
# ['5', ['4여신의 눈물', '4쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2거인의 허리띠', '2B.F. 대검', '1음전자 망토', '1연습용 장갑', '1곡궁'], '나무정령요술사']
# ['5', ['3음전자 망토', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2곡궁', '1여신의 눈물', '1거인의 허리띠', '1B.F. 대검'], '명사수귀감']
# ['1', ['4여신의 눈물', '4B.F. 대검', '3거인의 허리띠', '2음전자 망토', '2연습용 장갑', '2쇠사슬 조끼', '2곡궁', '1쓸데없이 큰 지팡이'], '명사수귀감']
# ['1', ['3음전자 망토', '3연습용 장갑', '3쓸데없이 큰 지팡이', '3쇠사슬 조끼', '3거인의 허리띠', '3B.F. 대검', '1여신의 눈물', '1곡궁'], '황혼']
# ['1', ['4거인의 허리띠', '4B.F. 대검', '3연습용 장갑', '2음전자 망토', '2쇠사슬 조끼', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1곡궁'], '달빛사냥꾼']
# ['3', ['3음전자 망토', '3쇠사슬 조끼', '2연습용 장갑', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2거인의 허리띠', '2B.F. 대검', '1뒤집개', '1곡궁'], '선봉대신비술사']
# ['5', ['3연습용 장갑', '3쇠사슬 조끼', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2거인의 허리띠', '2B.F. 대검', '1음전자 망토', '1곡궁'], '달빛사냥꾼']
# ['5', ['3음전자 망토', '3곡궁', '3거인의 허리띠', '2연습용 장갑', '2여신의 눈물', '2B.F. 대검', '1쇠사슬 조끼'], '그림자닌자']
# ['7', ['3음전자 망토', '3연습용 장갑', '3곡궁', '3B.F. 대검', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼'], '조율자결투가']
# ['6', ['4쓸데없이 큰 지팡이', '3음전자 망토', '2여신의 눈물', '2쇠사슬 조끼', '2곡궁', '2B.F. 대검', '1연습용 장갑', '1뒤집개'], '나무정령싸움꾼']
# ['2', ['4연습용 장갑', '4쓸데없이 큰 지팡이', '3음전자 망토', '3곡궁', '2쇠사슬 조끼', '1여신의 눈물', '1거인의 허리띠'], '황혼']
# ['3', ['4곡궁', '3여신의 눈물', '2연습용 장갑', '2거인의 허리띠', '1음전자 망토', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1B.F. 대검'], '신성조율자']
# ['4', ['5곡궁', '4B.F. 대검', '2여신의 눈물', '2쇠사슬 조끼', '1음전자 망토', '1연습용 장갑', '1뒤집개', '1거인의 허리띠'], '신성조율자']
# ['4', ['4연습용 장갑', '4여신의 눈물', '3음전자 망토', '2B.F. 대검', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1곡궁', '1거인의 허리띠'], '나무정령요술사']
# ['6', ['4쇠사슬 조끼', '4거인의 허리띠', '3연습용 장갑', '2음전자 망토', '2여신의 눈물', '1쓸데없이 큰 지팡이', '1B.F. 대검'], '달빛사냥꾼']
# ['3', ['5연습용 장갑', '5쓸데없이 큰 지팡이', '3쇠사슬 조끼', '3곡궁', '3거인의 허리띠', '2여신의 눈물', '1뒤집개', '1B.F. 대검'], '싸움꾼']
# ['5', ['5쇠사슬 조끼', '4음전자 망토', '3연습용 장갑', '3쓸데없이 큰 지팡이', '2곡궁'], '황혼']
# ['1', ['4연습용 장갑', '4여신의 눈물', '3거인의 허리띠', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2곡궁', '1음전자 망토', '1뒤집개', '1B.F. 대검'], '결투가']
# ['2', ['3여신의 눈물', '3거인의 허리띠', '3B.F. 대검', '2음전자 망토', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2곡궁', '1뒤집개'], '달빛사냥꾼']
# ['1', ['4곡궁', '3쓸데없이 큰 지팡이', '3거인의 허리띠', '3B.F. 대검', '2음전자 망토', '2연습용 장갑', '2쇠사슬 조끼', '1여신의 눈물'], '황혼']
# ['1', ['4음전자 망토', '4연습용 장갑', '3쓸데없이 큰 지팡이', '3곡궁', '3거인의 허리띠', '3B.F. 대검', '1여신의 눈물', '1뒤집개'], '나무정령싸움꾼']
# ['7', ['3쇠사슬 조끼', '2여신의 눈물', '2거인의 허리띠', '2B.F. 대검', '1음전자 망토', '1연습용 장갑', '1쓸데없이 큰 지팡이', '1뒤집개', '1곡궁'], '나무정령요술사']
# ['1', ['4거인의 허리띠', '3음전자 망토', '3곡궁', '3B.F. 대검', '2쇠사슬 조끼', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1뒤집개'], '신성조율자']
# ['3', ['5거인의 허리띠', '2음전자 망토', '2연습용 장갑', '2여신의 눈물', '2쇠사슬 조끼', '2B.F. 대검', '1쓸데없이 큰 지팡이', '1곡궁'], '달빛사냥꾼']
# ['4', ['4연습용 장갑', '4B.F. 대검', '3음전자 망토', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2곡궁', '2거인의 허리띠', '1뒤집개'], '명사수귀감']
# ['4', ['4거인의 허리띠', '3연습용 장갑', '3여신의 눈물', '3쇠사슬 조끼', '2쓸데없이 큰 지팡이', '1뒤집개', '1곡궁', '1B.F. 대검'], '달빛사냥꾼']
# ['1', ['5거인의 허리띠', '4쓸데없이 큰 지팡이', '3뒤집개', '2연습용 장갑', '1음전자 망토', '1여신의 눈물', '1쇠사슬 조끼', '1곡궁', '1B.F. 대검'], '싸움꾼']
# ['1', ['4쓸데없이 큰 지팡이', '4쇠사슬 조끼', '3B.F. 대검', '2곡궁', '2거인의 허리띠', '1음전자 망토', '1연습용 장갑', '1여신의 눈물'], '황혼']
# ['1', ['7여신의 눈물', '3곡궁', '2연습용 장갑', '2쇠사슬 조끼', '2뒤집개', '2거인의 허리띠', '1쓸데없이 큰 지팡이', '1B.F. 대검'], '결투가']
# ['2', ['4쇠사슬 조끼', '4B.F. 대검', '3연습용 장갑', '3쓸데없이 큰 지팡이', '3거인의 허리띠', '2음전자 망토', '2여신의 눈물', '2곡궁'], '달빛사냥꾼']
# ['3', ['5곡궁', '3음전자 망토', '3여신의 눈물', '3쇠사슬 조끼', '2거인의 허리띠', '2B.F. 대검', '1쓸데없이 큰 지팡이', '1뒤집개'], '신성조율자']
# ['5', ['3음전자 망토', '3쓸데없이 큰 지팡이', '2여신의 눈물', '2곡궁', '2B.F. 대검', '1쇠사슬 조끼', '1거인의 허리띠'], '선봉대신비술사']
# ['2', ['4곡궁', '4거인의 허리띠', '3B.F. 대검', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '1음전자 망토', '1연습용 장갑', '1여신의 눈물'], '싸움꾼']
# ['1', ['4연습용 장갑', '4쓸데없이 큰 지팡이', '3음전자 망토', '2여신의 눈물', '2쇠사슬 조끼', '2거인의 허리띠', '2B.F. 대검'], '선봉대신비술사']
# ['5', ['3음전자 망토', '3쇠사슬 조끼', '3B.F. 대검', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2곡궁', '1연습용 장갑', '1거인의 허리띠'], '황혼']
# ['3', ['4쓸데없이 큰 지팡이', '3B.F. 대검', '2음전자 망토', '2연습용 장갑', '2뒤집개', '2거인의 허리띠', '1여신의 눈물'], '나무정령싸움꾼']
# ['2', ['4쓸데없이 큰 지팡이', '4쇠사슬 조끼', '3음전자 망토', '2연습용 장갑', '2여신의 눈물', '2거인의 허리띠', '2B.F. 대검', '1뒤집개', '1곡궁'], '선봉대신비술사']
# ['1', ['4쇠사슬 조끼', '4거인의 허리띠', '3음전자 망토', '2쓸데없이 큰 지팡이', '2뒤집개', '2B.F. 대검', '1연습용 장갑', '1여신의 눈물', '1곡궁'], '황혼']
# ['4', ['4거인의 허리띠', '3여신의 눈물', '2쇠사슬 조끼', '2곡궁', '2B.F. 대검', '1음전자 망토', '1연습용 장갑', '1쓸데없이 큰 지팡이'], '신성조율자']
# ['3', ['4여신의 눈물', '4쓸데없이 큰 지팡이', '3쇠사슬 조끼', '2연습용 장갑', '2B.F. 대검', '1거인의 허리띠'], '나무정령요술사']
# ['5', ['3연습용 장갑', '3여신의 눈물', '3쇠사슬 조끼', '3거인의 허리띠', '2B.F. 대검', '1음전자 망토', '1곡궁'], '달빛사냥꾼']
# ['2', ['4B.F. 대검', '3음전자 망토', '3쇠사슬 조끼', '3거인의 허리띠', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2곡궁', '1연습용 장갑'], '명사수귀감']
# ['3', ['4쇠사슬 조끼', '4거인의 허리띠', '4B.F. 대검', '3여신의 눈물', '2연습용 장갑', '2곡궁', '1음전자 망토'], '나무정령요술사']
# ['2', ['3음전자 망토', '3연습용 장갑', '3쇠사슬 조끼', '3B.F. 대검', '2여신의 눈물', '2곡궁', '2거인의 허리띠'], '달빛사냥꾼']
# ['7', ['3연습용 장갑', '3곡궁', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '1음전자 망토', '1여신의 눈물', '1뒤집개', '1거인의 허리띠', '1B.F. 대검'], '명사수귀감']
# ['6', ['4연습용 장갑', '3쓸데없이 큰 지팡이', '2여신의 눈물', '2곡궁', '2거인의 허리띠', '1음전자 망토', '1쇠사슬 조끼', '1B.F. 대검'], '달빛사냥꾼']
# ['4', ['4쓸데없이 큰 지팡이', '3연습용 장갑', '2여신의 눈물', '2쇠사슬 조끼', '2곡궁', '2거인의 허리띠', '1음전자 망토', '1뒤집개'], '달빛사냥꾼']
# ['7', ['3음전자 망토', '3연습용 장갑', '2여신의 눈물', '2곡궁', '2B.F. 대검', '1쇠사슬 조끼', '1거인의 허리띠'], '선봉대신비술사']
# ['5', ['4음전자 망토', '4연습용 장갑', '3곡궁', '3B.F. 대검', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1거인의 허리띠'], '명사수귀감']
# ['1', ['5연습용 장갑', '5여신의 눈물', '5쓸데없이 큰 지팡이', '3쇠사슬 조끼', '2곡궁', '2거인의 허리띠', '2B.F. 대검'], '결투가']
# ['3', ['5연습용 장갑', '4여신의 눈물', '3음전자 망토', '3B.F. 대검', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2거인의 허리띠', '1곡궁'], '조율자결투가']
# ['2', ['5쇠사슬 조끼', '3여신의 눈물', '3쓸데없이 큰 지팡이', '2거인의 허리띠', '1음전자 망토', '1연습용 장갑', '1곡궁', '1B.F. 대검'], '황혼']
# ['2', ['5여신의 눈물', '4곡궁', '4B.F. 대검', '2음전자 망토', '2연습용 장갑', '2쓸데없이 큰 지팡이', '1거인의 허리띠'], '나무정령요술사']
# ['6', ['4거인의 허리띠', '3음전자 망토', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '1여신의 눈물', '1뒤집개', '1곡궁', '1B.F. 대검'], '선봉대신비술사']
# ['2', ['4연습용 장갑', '3음전자 망토', '3여신의 눈물', '3곡궁', '3거인의 허리띠', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2B.F. 대검'], '달빛사냥꾼']
# ['4', ['3음전자 망토', '2연습용 장갑', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2곡궁', '2거인의 허리띠', '1쇠사슬 조끼', '1뒤집개', '1B.F. 대검'], '선봉대신비술사']
# ['7', ['3음전자 망토', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2거인의 허리띠', '2B.F. 대검', '1곡궁'], '선봉대신비술사']
# ['2', ['4연습용 장갑', '3여신의 눈물', '3쓸데없이 큰 지팡이', '3쇠사슬 조끼', '3거인의 허리띠', '2음전자 망토', '2곡궁'], '달빛사냥꾼']
# ['7', ['3B.F. 대검', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2곡궁', '2거인의 허리띠', '1음전자 망토', '1연습용 장갑', '1여신의 눈물'], '명사수귀감']
# ['6', ['4연습용 장갑', '2음전자 망토', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2곡궁', '1B.F. 대검'], '명사수귀감']
# ['5', ['5쓸데없이 큰 지팡이', '3음전자 망토', '3곡궁', '2거인의 허리띠', '2B.F. 대검', '1여신의 눈물', '1쇠사슬 조끼', '1뒤집개'], '나무정령싸움꾼']
# ['3', ['5쓸데없이 큰 지팡이', '3연습용 장갑', '2여신의 눈물', '2쇠사슬 조끼', '2곡궁', '2거인의 허리띠', '1음전자 망토', '1B.F. 대검'], '달빛사냥꾼']
# ['4', ['4연습용 장갑', '4쇠사슬 조끼', '3음전자 망토', '3쓸데없이 큰 지팡이', '1곡궁'], '황혼']
# ['1', ['4음전자 망토', '3B.F. 대검', '2연습용 장갑', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2곡궁', '2거인의 허리띠', '1쇠사슬 조끼'], '선봉대신비술사']
# ['2', ['5쓸데없이 큰 지팡이', '4곡궁', '4B.F. 대검', '3연습용 장갑', '3쇠사슬 조끼', '2음전자 망토', '2여신의 눈물', '2뒤집개', '2거인의 허리띠'], '황혼']
# ['2', ['4음전자 망토', '4곡궁', '4B.F. 대검', '2연습용 장갑', '2거인의 허리띠', '1여신의 눈물', '1쓸데없이 큰 지팡이'], '그림자닌자']
# ['2', ['6쇠사슬 조끼', '4쓸데없이 큰 지팡이', '3곡궁', '2연습용 장갑', '2거인의 허리띠', '2B.F. 대검', '1음전자 망토', '1여신의 눈물'], '황혼']
# ['3', ['3음전자 망토', '3여신의 눈물', '3곡궁', '2연습용 장갑', '2B.F. 대검', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1거인의 허리띠'], '신성조율자']
# ['1', ['5쓸데없이 큰 지팡이', '4B.F. 대검', '3쇠사슬 조끼', '3곡궁', '2거인의 허리띠', '1음전자 망토'], '황혼']
# ['1', ['3쓸데없이 큰 지팡이', '3쇠사슬 조끼', '3뒤집개', '3곡궁', '3거인의 허리띠', '2B.F. 대검', '1음전자 망토'], '황혼']
# ['7', ['4곡궁', '2음전자 망토', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2거인의 허리띠', '1여신의 눈물', '1쇠사슬 조끼'], '명사수귀감']
# ['4', ['4곡궁', '4거인의 허리띠', '3여신의 눈물', '3쓸데없이 큰 지팡이', '2연습용 장갑', '2쇠사슬 조끼', '2B.F. 대검', '1음전자 망토'], '싸움꾼']
# ['6', ['5연습용 장갑', '5거인의 허리띠', '3음전자 망토', '3쇠사슬 조끼', '3곡궁', '2쓸데없이 큰 지팡이', '1여신의 눈물', '1B.F. 대검'], '싸움꾼']
# ['1', ['4여신의 눈물', '4쇠사슬 조끼', '3거인의 허리띠', '2연습용 장갑', '2뒤집개', '2B.F. 대검', '1음전자 망토', '1쓸데없이 큰 지팡이', '1곡궁'], '나무정령요술사']
# ['1', ['4음전자 망토', '4쇠사슬 조끼', '3여신의 눈물', '2쓸데없이 큰 지팡이', '2B.F. 대검', '1연습용 장갑', '1뒤집개', '1거인의 허리띠'], '나무정령요술사']
# ['4', ['4쇠사슬 조끼', '3여신의 눈물', '3곡궁', '2음전자 망토', '2연습용 장갑', '2쓸데없이 큰 지팡이', '1거인의 허리띠'], '신성조율자']
# ['7', ['3쓸데없이 큰 지팡이', '3곡궁', '2음전자 망토', '2연습용 장갑', '2B.F. 대검', '1여신의 눈물', '1쇠사슬 조끼'], '나무정령싸움꾼']
# ['2', ['4쇠사슬 조끼', '4B.F. 대검', '3곡궁', '2음전자 망토', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2거인의 허리띠', '1연습용 장갑'], '명사수귀감']
# ['4', ['4거인의 허리띠', '3쓸데없이 큰 지팡이', '3B.F. 대검', '1음전자 망토', '1연습용 장갑', '1여신의 눈물', '1쇠사슬 조끼', '1뒤집개', '1곡궁'], '달빛사냥꾼']
# ['2', ['6여신의 눈물', '4연습용 장갑', '4쓸데없이 큰 지팡이', '2음전자 망토', '2쇠사슬 조끼', '2곡궁', '2B.F. 대검', '1뒤집개', '1거인의 허리띠'], '나무정령요술사']
# ['4', ['4쓸데없이 큰 지팡이', '4거인의 허리띠', '2여신의 눈물', '2쇠사슬 조끼', '1음전자 망토', '1연습용 장갑', '1곡궁', '1B.F. 대검'], '달빛사냥꾼']
# ['6', ['2음전자 망토', '2연습용 장갑', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2거인의 허리띠', '1곡궁', '1B.F. 대검'], '선봉대신비술사']
# ['4', ['4음전자 망토', '3쓸데없이 큰 지팡이', '3쇠사슬 조끼', '2거인의 허리띠', '2B.F. 대검', '1연습용 장갑', '1여신의 눈물'], '황혼']
# ['3', ['4쇠사슬 조끼', '3거인의 허리띠', '2음전자 망토', '2연습용 장갑', '2여신의 눈물', '2B.F. 대검', '1쓸데없이 큰 지팡이', '1곡궁'], '달빛사냥꾼']
# ['2', ['4쓸데없이 큰 지팡이', '3음전자 망토', '3연습용 장갑', '3거인의 허리띠', '3B.F. 대검', '2여신의 눈물', '1쇠사슬 조끼', '1뒤집개', '1곡궁'], '달빛사냥꾼']
# ['1', ['6여신의 눈물', '3음전자 망토', '3연습용 장갑', '3쓸데없이 큰 지팡이', '3곡궁', '3B.F. 대검', '2쇠사슬 조끼', '2거인의 허리띠', '1뒤집개'], '나무정령요술사']
# ['6', ['6여신의 눈물', '4거인의 허리띠', '3쓸데없이 큰 지팡이', '3B.F. 대검', '2쇠사슬 조끼', '1음전자 망토', '1연습용 장갑'], '달빛사냥꾼']
# ['1', ['5여신의 눈물', '4거인의 허리띠', '3음전자 망토', '3연습용 장갑', '3쇠사슬 조끼', '3곡궁', '3B.F. 대검', '2쓸데없이 큰 지팡이'], '달빛사냥꾼']
# ['8', ['3곡궁', '2음전자 망토', '1연습용 장갑', '1쓸데없이 큰 지팡이', '1거인의 허리띠', '1B.F. 대검'], '신성조율자']
# ['4', ['4곡궁', '3쇠사슬 조끼', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2뒤집개', '2거인의 허리띠', '2B.F. 대검', '1음전자 망토'], '황혼']
# ['1', ['5B.F. 대검', '4거인의 허리띠', '3쇠사슬 조끼', '2음전자 망토', '2여신의 눈물', '2쓸데없이 큰 지팡이', '1곡궁'], '달빛사냥꾼']
# ['1', ['6여신의 눈물', '2음전자 망토', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2거인의 허리띠', '2B.F. 대검', '1곡궁'], '나무정령요술사']
# ['2', ['5곡궁', '4음전자 망토', '3쇠사슬 조끼', '2거인의 허리띠', '1연습용 장갑', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1뒤집개'], '신성조율자']
# ['7', ['2연습용 장갑', '2곡궁', '2거인의 허리띠', '2B.F. 대검', '1음전자 망토', '1여신의 눈물'], '결투가']
# ['4', ['5음전자 망토', '4연습용 장갑', '4거인의 허리띠', '2쇠사슬 조끼', '2곡궁', '1쓸데없이 큰 지팡이', '1뒤집개', '1B.F. 대검'], '광신도']
# ['5', ['3음전자 망토', '2여신의 눈물', '2쇠사슬 조끼', '2곡궁', '2B.F. 대검', '1연습용 장갑', '1쓸데없이 큰 지팡이', '1거인의 허리띠'], '신성조율자']
# ['1', ['5쓸데없이 큰 지팡이', '5B.F. 대검', '3쇠사슬 조끼', '3곡궁', '2음전자 망토', '2여신의 눈물', '2거인의 허리띠', '1뒤집개', '10연습용 장갑'], '황혼']
# ['1', ['4거인의 허리띠', '3음전자 망토', '3쓸데없이 큰 지팡이', '2연습용 장갑', '2여신의 눈물', '2쇠사슬 조끼', '2곡궁', '1뒤집개', '1B.F. 대검'], '선봉대신비술사']
# ['3', ['4여신의 눈물', '3쇠사슬 조끼', '2음전자 망토', '2연습용 장갑', '2B.F. 대검', '1쓸데없이 큰 지팡이', '1곡궁', '1거인의 허리띠'], '나무정령요술사']
# ['2', ['4곡궁', '4거인의 허리띠', '3여신의 눈물', '3B.F. 대검', '2쇠사슬 조끼', '1연습용 장갑', '1쓸데없이 큰 지팡이'], '신성조율자']
# ['2', ['5B.F. 대검', '4쇠사슬 조끼', '3연습용 장갑', '3뒤집개', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2곡궁', '2거인의 허리띠'], '달빛사냥꾼']
# ['5', ['4여신의 눈물', '4곡궁', '3연습용 장갑', '2뒤집개', '1음전자 망토', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1거인의 허리띠'], '나무정령요술사']
# ['8', ['3연습용 장갑', '3쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2곡궁', '1음전자 망토', '1여신의 눈물', '1B.F. 대검'], '황혼']
# ['1', ['5쇠사슬 조끼', '3음전자 망토', '3여신의 눈물', '3곡궁', '3거인의 허리띠', '2연습용 장갑', '2B.F. 대검'], '신성조율자']
# ['6', ['5쇠사슬 조끼', '4곡궁', '4B.F. 대검', '2음전자 망토', '2연습용 장갑', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1뒤집개', '1거인의 허리띠'], '명사수귀감']
# ['5', ['4연습용 장갑', '3음전자 망토', '3B.F. 대검', '2여신의 눈물', '2곡궁', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1뒤집개'], '조율자결투가']
# ['4', ['4쓸데없이 큰 지팡이', '3거인의 허리띠', '2음전자 망토', '2연습용 장갑', '2쇠사슬 조끼', '2B.F. 대검', '1여신의 눈물'], '황혼']
# ['3', ['3쇠사슬 조끼', '2음전자 망토', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2곡궁', '2거인의 허리띠', '2B.F. 대검', '1여신의 눈물'], '황혼']
# ['6', ['3연습용 장갑', '3B.F. 대검', '2쇠사슬 조끼', '2거인의 허리띠', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1뒤집개', '1곡궁'], '달빛사냥꾼']
# ['5', ['4쇠사슬 조끼', '3곡궁', '2여신의 눈물', '2뒤집개', '2거인의 허리띠', '1음전자 망토', '1연습용 장갑', '1쓸데없이 큰 지팡이', '1B.F. 대검'], '나무정령요술사']
# ['4', ['4연습용 장갑', '4B.F. 대검', '3쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2거인의 허리띠', '1음전자 망토', '1여신의 눈물', '1뒤집개', '1곡궁'], '달빛사냥꾼']
# ['1', ['3여신의 눈물', '3쇠사슬 조끼', '3곡궁', '2쓸데없이 큰 지팡이', '2거인의 허리띠', '2B.F. 대검', '1연습용 장갑'], '신성조율자']
# ['5', ['4음전자 망토', '3연습용 장갑', '3B.F. 대검', '2쇠사슬 조끼', '2거인의 허리띠', '1쓸데없이 큰 지팡이', '1뒤집개'], '광신도']
# ['2', ['5곡궁', '4쓸데없이 큰 지팡이', '4거인의 허리띠', '2연습용 장갑', '1여신의 눈물', '1쇠사슬 조끼', '1B.F. 대검'], '싸움꾼']
# ['4', ['3음전자 망토', '3쓸데없이 큰 지팡이', '2연습용 장갑', '2여신의 눈물', '2쇠사슬 조끼', '2거인의 허리띠', '1뒤집개', '1B.F. 대검'], '선봉대신비술사']
# ['2', ['5쇠사슬 조끼', '4곡궁', '3여신의 눈물', '3쓸데없이 큰 지팡이', '2음전자 망토', '2B.F. 대검', '1거인의 허리띠'], '신성조율자']
# ['3', ['3음전자 망토', '3쓸데없이 큰 지팡이', '3거인의 허리띠', '2쇠사슬 조끼', '2B.F. 대검', '1연습용 장갑', '1여신의 눈물', '1뒤집개', '1곡궁'], '선봉대신비술사']
# ['5', ['4여신의 눈물', '4쓸데없이 큰 지팡이', '3쇠사슬 조끼', '2음전자 망토', '2곡궁', '2B.F. 대검', '1연습용 장갑', '1뒤집개', '1거인의 허리띠'], '나무정령요술사']
# ['5', ['4연습용 장갑', '4여신의 눈물', '3B.F. 대검', '2곡궁', '1음전자 망토', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼'], '조율자결투가']
# ['1', ['5쇠사슬 조끼', '2여신의 눈물', '2곡궁', '2B.F. 대검', '1음전자 망토', '1연습용 장갑', '1쓸데없이 큰 지팡이', '1거인의 허리띠'], '나무정령요술사']
# ['1', ['7연습용 장갑', '5쇠사슬 조끼', '3음전자 망토', '3쓸데없이 큰 지팡이', '3거인의 허리띠', '2B.F. 대검', '1여신의 눈물', '1뒤집개', '1곡궁'], '황혼']
# ['4', ['4여신의 눈물', '4곡궁', '2음전자 망토', '2연습용 장갑', '2쇠사슬 조끼', '2B.F. 대검', '1쓸데없이 큰 지팡이', '1뒤집개'], '나무정령요술사']
# ['4', ['4거인의 허리띠', '3쇠사슬 조끼', '2연습용 장갑', '2여신의 눈물', '2B.F. 대검', '1음전자 망토', '1쓸데없이 큰 지팡이'], '달빛사냥꾼']
# ['4', ['4음전자 망토', '3연습용 장갑', '3여신의 눈물', '3B.F. 대검', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1곡궁', '1거인의 허리띠'], '조율자결투가']
# ['3', ['4B.F. 대검', '3음전자 망토', '3여신의 눈물', '3곡궁', '3거인의 허리띠', '2쓸데없이 큰 지팡이', '1쇠사슬 조끼'], '신성조율자']
# ['1', ['6곡궁', '3음전자 망토', '3B.F. 대검', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '1여신의 눈물', '1거인의 허리띠'], '명사수귀감']
# ['5', ['5여신의 눈물', '4쓸데없이 큰 지팡이', '4곡궁', '3쇠사슬 조끼', '2음전자 망토', '2B.F. 대검', '1연습용 장갑', '1거인의 허리띠'], '신성조율자']
# ['2', ['4쇠사슬 조끼', '3여신의 눈물', '3B.F. 대검', '2음전자 망토', '2연습용 장갑', '2거인의 허리띠', '1쓸데없이 큰 지팡이', '1곡궁'], '나무정령요술사']
# ['8', ['3곡궁', '2음전자 망토', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2B.F. 대검', '1여신의 눈물', '1거인의 허리띠'], '명사수귀감']
# ['1', ['5여신의 눈물', '3쓸데없이 큰 지팡이', '3뒤집개', '3곡궁', '3B.F. 대검', '2음전자 망토', '1연습용 장갑', '1쇠사슬 조끼'], '나무정령요술사']
# ['2', ['4쓸데없이 큰 지팡이', '4곡궁', '3음전자 망토', '2연습용 장갑', '2여신의 눈물', '2거인의 허리띠', '2B.F. 대검', '1쇠사슬 조끼'], '선봉대신비술사']
# ['1', ['3쓸데없이 큰 지팡이', '3B.F. 대검', '2음전자 망토', '2여신의 눈물', '2쇠사슬 조끼', '2곡궁', '1연습용 장갑', '1뒤집개', '1거인의 허리띠'], '나무정령싸움꾼']
# ['7', ['3쓸데없이 큰 지팡이', '2연습용 장갑', '2여신의 눈물', '2곡궁', '2B.F. 대검', '1음전자 망토', '1쇠사슬 조끼', '1거인의 허리띠'], '나무정령싸움꾼']
# ['4', ['3음전자 망토', '3쓸데없이 큰 지팡이', '3쇠사슬 조끼', '3B.F. 대검', '2거인의 허리띠', '1연습용 장갑', '1곡궁'], '황혼']
# ['3', ['4여신의 눈물', '2음전자 망토', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2뒤집개', '2곡궁', '1거인의 허리띠', '1B.F. 대검'], '나무정령요술사']
# ['2', ['4음전자 망토', '4곡궁', '3여신의 눈물', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2거인의 허리띠', '1연습용 장갑', '1뒤집개', '1B.F. 대검'], '신성조율자']
# ['3', ['6거인의 허리띠', '3곡궁', '2여신의 눈물', '2쓸데없이 큰 지팡이', '1음전자 망토', '1연습용 장갑', '1B.F. 대검'], '싸움꾼']
# ['7', ['4여신의 눈물', '3쇠사슬 조끼', '2쓸데없이 큰 지팡이', '2뒤집개', '2거인의 허리띠', '2B.F. 대검', '1음전자 망토', '1연습용 장갑'], '나무정령요술사']
# ['2', ['5곡궁', '5거인의 허리띠', '4연습용 장갑', '3쇠사슬 조끼', '2음전자 망토', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2뒤집개', '2B.F. 대검'], '싸움꾼']
# ['2', ['3연습용 장갑', '3여신의 눈물', '3쓸데없이 큰 지팡이', '3쇠사슬 조끼', '2음전자 망토', '2B.F. 대검', '1뒤집개', '1곡궁'], '나무정령요술사']
# ['1', ['7여신의 눈물', '4쓸데없이 큰 지팡이', '3연습용 장갑', '3뒤집개', '2B.F. 대검', '1음전자 망토', '1쇠사슬 조끼', '1곡궁', '1거인의 허리띠'], '나무정령요술사']
# ['3', ['7곡궁', '3연습용 장갑', '3여신의 눈물', '3쓸데없이 큰 지팡이', '2거인의 허리띠', '2B.F. 대검', '1음전자 망토', '1쇠사슬 조끼', '1뒤집개'], '달빛사냥꾼']
# ['7', ['4곡궁', '3쇠사슬 조끼', '2여신의 눈물', '2쓸데없이 큰 지팡이', '1음전자 망토', '1거인의 허리띠', '1B.F. 대검'], '신성조율자']
# ['6', ['4연습용 장갑', '4여신의 눈물', '3쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2거인의 허리띠', '1음전자 망토', '1곡궁', '1B.F. 대검'], '달빛사냥꾼']
# ['2', ['4음전자 망토', '4쓸데없이 큰 지팡이', '3B.F. 대검', '2연습용 장갑', '2여신의 눈물', '2곡궁', '1쇠사슬 조끼', '1거인의 허리띠'], '나무정령싸움꾼']
# ['5', ['3여신의 눈물', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2B.F. 대검', '1뒤집개', '1곡궁', '1거인의 허리띠'], '나무정령요술사']
# ['1', ['4여신의 눈물', '4쓸데없이 큰 지팡이', '3곡궁', '3B.F. 대검', '2거인의 허리띠', '1쇠사슬 조끼'], '신성조율자']
# ['3', ['6여신의 눈물', '4B.F. 대검', '3쓸데없이 큰 지팡이', '2음전자 망토', '1연습용 장갑', '1쇠사슬 조끼', '1뒤집개', '1거인의 허리띠'], '나무정령요술사']
# ['2', ['5여신의 눈물', '3음전자 망토', '3연습용 장갑', '3쓸데없이 큰 지팡이', '3B.F. 대검', '2쇠사슬 조끼', '1곡궁'], '조율자결투가']
# ['4', ['4여신의 눈물', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2곡궁', '2거인의 허리띠', '2B.F. 대검', '1음전자 망토', '1연습용 장갑', '1뒤집개'], '결투가']
# ['2', ['4음전자 망토', '4연습용 장갑', '4여신의 눈물', '4곡궁', '4거인의 허리띠', '3B.F. 대검', '2쇠사슬 조끼', '1쓸데없이 큰 지팡이'], '조율자결투가']
# ['3', ['5여신의 눈물', '4연습용 장갑', '3쇠사슬 조끼', '3거인의 허리띠', '2음전자 망토', '1쓸데없이 큰 지팡이'], '조율자결투가']
# ['7', ['3여신의 눈물', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2B.F. 대검', '1음전자 망토', '1쇠사슬 조끼', '1곡궁'], '나무정령요술사']
# ['1', ['6여신의 눈물', '4연습용 장갑', '4거인의 허리띠', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2곡궁', '1음전자 망토', '1B.F. 대검'], '달빛사냥꾼']
# ['7', ['4쇠사슬 조끼', '2음전자 망토', '2곡궁', '1연습용 장갑', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1거인의 허리띠'], '황혼']
# ['3', ['5쇠사슬 조끼', '4쓸데없이 큰 지팡이', '4거인의 허리띠', '2음전자 망토', '2B.F. 대검', '1여신의 눈물', '1곡궁'], '황혼']
# ['1', ['3연습용 장갑', '2음전자 망토', '2쓸데없이 큰 지팡이', '2곡궁', '2거인의 허리띠', '1여신의 눈물', '1쇠사슬 조끼', '1B.F. 대검'], '달빛사냥꾼']
# ['3', ['5B.F. 대검', '4쇠사슬 조끼', '2연습용 장갑', '2곡궁', '2거인의 허리띠', '1여신의 눈물', '1쓸데없이 큰 지팡이'], '명사수귀감']
# ['5', ['3연습용 장갑', '3여신의 눈물', '3거인의 허리띠', '2음전자 망토', '2쓸데없이 큰 지팡이', '2B.F. 대검', '1뒤집개'], '달빛사냥꾼']
# ['1', ['4음전자 망토', '4B.F. 대검', '3곡궁', '2연습용 장갑', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '1거인의 허리띠'], '명사수귀감']
# ['3', ['3음전자 망토', '3거인의 허리띠', '2연습용 장갑', '2쇠사슬 조끼', '2뒤집개', '2B.F. 대검', '1여신의 눈물', '1곡궁'], '선봉대신비술사']
# ['3', ['4B.F. 대검', '3거인의 허리띠', '2연습용 장갑', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2곡궁', '1음전자 망토', '1쇠사슬 조끼'], '달빛사냥꾼']
# ['1', ['5거인의 허리띠', '3연습용 장갑', '3쓸데없이 큰 지팡이', '3쇠사슬 조끼', '2B.F. 대검', '1음전자 망토', '1여신의 눈물', '1뒤집개', '1곡궁'], '달빛사냥꾼']
# ['1', ['3음전자 망토', '3연습용 장갑', '3여신의 눈물', '3곡궁', '2거인의 허리띠', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1B.F. 대검'], '선봉대신비술사']
# ['4', ['4쇠사슬 조끼', '2음전자 망토', '2연습용 장갑', '2여신의 눈물', '2곡궁', '1쓸데없이 큰 지팡이', '1뒤집개', '1거인의 허리띠', '1B.F. 대검'], '나무정령요술사']
# ['3', ['5B.F. 대검', '3쓸데없이 큰 지팡이', '3곡궁', '3거인의 허리띠', '2연습용 장갑', '2여신의 눈물', '1쇠사슬 조끼'], '달빛사냥꾼']
# ['2', ['3연습용 장갑', '3쇠사슬 조끼', '3거인의 허리띠', '2음전자 망토', '2B.F. 대검', '1쓸데없이 큰 지팡이', '1뒤집개', '1곡궁'], '달빛사냥꾼']
# ['2', ['5쇠사슬 조끼', '4여신의 눈물', '4쓸데없이 큰 지팡이', '3연습용 장갑', '3곡궁', '1거인의 허리띠'], '나무정령요술사']
# ['8', ['4거인의 허리띠', '3연습용 장갑', '3쓸데없이 큰 지팡이', '2여신의 눈물', '1음전자 망토', '1쇠사슬 조끼', '1곡궁'], '달빛사냥꾼']
# ['6', ['3곡궁', '2음전자 망토', '2연습용 장갑', '2쇠사슬 조끼', '2뒤집개', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1B.F. 대검'], '명사수귀감']
# ['7', ['3연습용 장갑', '3여신의 눈물', '3쓸데없이 큰 지팡이', '2B.F. 대검', '1음전자 망토', '1곡궁', '1거인의 허리띠'], '달빛사냥꾼']
# ['6', ['4연습용 장갑', '3쓸데없이 큰 지팡이', '3곡궁', '2음전자 망토', '2여신의 눈물', '2쇠사슬 조끼', '2거인의 허리띠', '1뒤집개', '1B.F. 대검'], '나무정령싸움꾼']
# ['6', ['5곡궁', '4연습용 장갑', '3B.F. 대검', '2여신의 눈물', '2거인의 허리띠', '1음전자 망토', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼'], '달빛사냥꾼']
# ['7', ['3쓸데없이 큰 지팡이', '3쇠사슬 조끼', '3B.F. 대검', '1음전자 망토', '1연습용 장갑', '1거인의 허리띠'], '황혼']
# ['2', ['5여신의 눈물', '3곡궁', '2연습용 장갑', '2쇠사슬 조끼', '2거인의 허리띠', '2B.F. 대검', '1음전자 망토', '1쓸데없이 큰 지팡이'], '결투가']
# ...
# ['8', ['4B.F. 대검', '2음전자 망토', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2곡궁', '2거인의 허리띠', '1연습용 장갑', '1쇠사슬 조끼'], '명사수귀감']
# ['1', ['5여신의 눈물', '4곡궁', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2B.F. 대검', '1음전자 망토', '1연습용 장갑', '1거인의 허리띠'], '신성조율자']
# ['7', ['2곡궁', '1음전자 망토', '1연습용 장갑', '1쓸데없이 큰 지팡이'], '명사수귀감']
# ['2', ['4여신의 눈물', '3음전자 망토', '3연습용 장갑', '3쇠사슬 조끼', '3B.F. 대검', '2쓸데없이 큰 지팡이', '2곡궁', '2거인의 허리띠'], '조율자결투가']
# ['6', ['4연습용 장갑', '3음전자 망토', '2여신의 눈물', '2곡궁', '1쓸데없이 큰 지팡이', '1뒤집개', '1거인의 허리띠'], '나무정령요술사']
# ['3', ['3연습용 장갑', '3쓸데없이 큰 지팡이', '3쇠사슬 조끼', '3곡궁', '2음전자 망토', '2여신의 눈물', '2거인의 허리띠', '2B.F. 대검', '1뒤집개'], '황혼']
# ['2', ['5곡궁', '3여신의 눈물', '3쓸데없이 큰 지팡이', '2음전자 망토', '2뒤집개', '2거인의 허리띠', '1연습용 장갑', '1쇠사슬 조끼', '1B.F. 대검'], '나무정령요술사']
# ['2', ['3여신의 눈물', '3쓸데없이 큰 지팡이', '3쇠사슬 조끼', '3B.F. 대검', '2음전자 망토', '2연습용 장갑', '2곡궁', '2거인의 허리띠', '1뒤집개'], '황혼']
# ['4', ['5연습용 장갑', '4곡궁', '2음전자 망토', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2거인의 허리띠', '1여신의 눈물', '1B.F. 대검'], '명사수귀감']
# ['2', ['5쓸데없이 큰 지팡이', '5B.F. 대검', '3연습용 장갑', '2뒤집개', '2곡궁', '2거인의 허리띠', '1여신의 눈물'], '나무정령싸움꾼']
# ['2', ['4쓸데없이 큰 지팡이', '3연습용 장갑', '3거인의 허리띠', '3B.F. 대검', '2음전자 망토', '2여신의 눈물', '2쇠사슬 조끼', '2뒤집개', '2곡궁'], '달빛사냥꾼']
# ['7', ['4연습용 장갑', '3여신의 눈물', '3쓸데없이 큰 지팡이', '2음전자 망토', '2곡궁', '2거인의 허리띠', '1쇠사슬 조끼', '1B.F. 대검'], '선봉대신비술사']
# ['2', ['5쇠사슬 조끼', '4음전자 망토', '4연습용 장갑', '4거인의 허리띠', '3곡궁', '3B.F. 대검', '1여신의 눈물', '1쓸데없이 큰 지팡이'], '그림자닌자']
# ['3', ['3연습용 장갑', '3쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2곡궁', '2거인의 허리띠', '1음전자 망토', '1여신의 눈물', '1뒤집개', '1B.F. 대검'], '나무정령싸움꾼']
# ['7', ['6여신의 눈물', '2음전자 망토', '2B.F. 대검', '1연습용 장갑', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1뒤집개', '1거인의 허리띠'], '나무정령요술사']
# ['7', ['3곡궁', '2음전자 망토', '2연습용 장갑', '2거인의 허리띠', '2B.F. 대검', '1쓸데없이 큰 지팡이'], '그림자닌자']
# ['4', ['4음전자 망토', '4거인의 허리띠', '3여신의 눈물', '3곡궁', '2연습용 장갑', '2B.F. 대검', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼'], '선봉대신비술사']
# ['2', ['3음전자 망토', '3여신의 눈물', '3쓸데없이 큰 지팡이', '3쇠사슬 조끼', '2곡궁', '1연습용 장갑', '1뒤집개', '1거인의 허리띠', '1B.F. 대검'], '나무정령요술사']
# ['2', ['4여신의 눈물', '4곡궁', '3거인의 허리띠', '3B.F. 대검', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '1음전자 망토', '1뒤집개'], '결투가']
# ['2', ['4음전자 망토', '4곡궁', '3여신의 눈물', '3B.F. 대검', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2뒤집개', '2거인의 허리띠', '1연습용 장갑'], '신성조율자']
# ['8', ['2쇠사슬 조끼', '2곡궁', '2거인의 허리띠', '2B.F. 대검', '1음전자 망토', '1연습용 장갑', '1여신의 눈물', '1쓸데없이 큰 지팡이'], '명사수귀감']
# ['8', ['3여신의 눈물', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2B.F. 대검', '1뒤집개', '1곡궁', '1거인의 허리띠'], '나무정령요술사']
# ['2', ['5연습용 장갑', '5여신의 눈물', '5쓸데없이 큰 지팡이', '5B.F. 대검', '3쇠사슬 조끼', '3곡궁', '3거인의 허리띠', '2음전자 망토', '2뒤집개'], '달빛사냥꾼']
# ['1', ['3음전자 망토', '3여신의 눈물', '3쇠사슬 조끼', '3곡궁', '2쓸데없이 큰 지팡이', '2거인의 허리띠', '2B.F. 대검', '1연습용 장갑'], '신성조율자']
# ['7', ['3B.F. 대검', '2음전자 망토', '2쇠사슬 조끼', '2거인의 허리띠', '1연습용 장갑', '1여신의 눈물', '1곡궁'], '황혼']
# ['2', ['4음전자 망토', '4여신의 눈물', '4쓸데없이 큰 지팡이', '3곡궁', '3B.F. 대검', '2쇠사슬 조끼', '1연습용 장갑'], '신성조율자']
# ['3', ['4여신의 눈물', '3거인의 허리띠', '2음전자 망토', '2쇠사슬 조끼', '2곡궁', '2B.F. 대검', '1연습용 장갑', '1쓸데없이 큰 지팡이', '1뒤집개'], '결투가']
# ['5', ['5연습용 장갑', '5B.F. 대검', '3음전자 망토', '3쓸데없이 큰 지팡이', '3쇠사슬 조끼', '2곡궁', '2거인의 허리띠', '1여신의 눈물'], '황혼']
# ['6', ['3여신의 눈물', '2음전자 망토', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2거인의 허리띠', '1곡궁'], '나무정령요술사']
# ['4', ['3연습용 장갑', '3여신의 눈물', '3쇠사슬 조끼', '3거인의 허리띠', '2쓸데없이 큰 지팡이', '2곡궁', '2B.F. 대검', '1음전자 망토', '1뒤집개'], '달빛사냥꾼']
# ['2', ['5연습용 장갑', '4곡궁', '3음전자 망토', '3여신의 눈물', '3쓸데없이 큰 지팡이', '3B.F. 대검', '2쇠사슬 조끼', '2거인의 허리띠', '1뒤집개'], '나무정령싸움꾼']
# ['7', ['2연습용 장갑', '2여신의 눈물', '2곡궁', '2거인의 허리띠', '1음전자 망토', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1B.F. 대검'], '달빛사냥꾼']
# ['1', ['4곡궁', '3음전자 망토', '3거인의 허리띠', '2연습용 장갑', '2쇠사슬 조끼', '2B.F. 대검', '1여신의 눈물', '1쓸데없이 큰 지팡이'], '그림자닌자']
# ['1', ['5쇠사슬 조끼', '4음전자 망토', '3쓸데없이 큰 지팡이', '3곡궁', '2여신의 눈물', '2B.F. 대검', '1연습용 장갑'], '황혼']
# ['2', ['6쓸데없이 큰 지팡이', '5음전자 망토', '3연습용 장갑', '3쇠사슬 조끼', '2여신의 눈물', '2B.F. 대검', '1뒤집개'], '황혼']
# ['1', ['4거인의 허리띠', '3곡궁', '2음전자 망토', '2여신의 눈물', '2쇠사슬 조끼', '1연습용 장갑', '1쓸데없이 큰 지팡이', '1B.F. 대검'], '신성조율자']
# ['8', ['3여신의 눈물', '2음전자 망토', '2연습용 장갑', '2B.F. 대검', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1곡궁'], '나무정령요술사']
# ['2', ['5거인의 허리띠', '4연습용 장갑', '3음전자 망토', '2쇠사슬 조끼', '2곡궁', '2B.F. 대검', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1뒤집개'], '싸움꾼']
# ['4', ['4연습용 장갑', '4쇠사슬 조끼', '4거인의 허리띠', '4B.F. 대검', '3음전자 망토', '1쓸데없이 큰 지팡이', '1곡궁'], '광신도']
# ['2', ['4연습용 장갑', '3음전자 망토', '3쓸데없이 큰 지팡이', '3쇠사슬 조끼', '2여신의 눈물', '2B.F. 대검', '1뒤집개', '1곡궁', '1거인의 허리띠'], '황혼']
# ['5', ['5음전자 망토', '3거인의 허리띠', '3B.F. 대검', '1연습용 장갑', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1곡궁'], '광신도']
# ['4', ['4음전자 망토', '4쇠사슬 조끼', '3거인의 허리띠', '2여신의 눈물', '2곡궁', '2B.F. 대검', '1연습용 장갑', '1쓸데없이 큰 지팡이', '1뒤집개'], '나무정령요술사']
# ['1', ['4곡궁', '3여신의 눈물', '2쇠사슬 조끼', '2거인의 허리띠', '1음전자 망토', '1연습용 장갑', '1쓸데없이 큰 지팡이', '1뒤집개', '1B.F. 대검'], '신성조율자']
# ['4', ['3음전자 망토', '3쓸데없이 큰 지팡이', '2여신의 눈물', '2쇠사슬 조끼', '2곡궁', '2B.F. 대검', '1연습용 장갑', '1뒤집개'], '나무정령싸움꾼']
# ['5', ['6여신의 눈물', '3연습용 장갑', '3거인의 허리띠', '3B.F. 대검', '1음전자 망토', '1쇠사슬 조끼'], '달빛사냥꾼']
# ['1', ['5여신의 눈물', '4B.F. 대검', '3쓸데없이 큰 지팡이', '3쇠사슬 조끼', '3거인의 허리띠', '1음전자 망토', '1연습용 장갑'], '달빛사냥꾼']
# ['2', ['6쓸데없이 큰 지팡이', '4쇠사슬 조끼', '3연습용 장갑', '2B.F. 대검', '1음전자 망토', '1뒤집개', '1곡궁', '1거인의 허리띠'], '황혼']
# ['2', ['5곡궁', '4B.F. 대검', '2음전자 망토', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2뒤집개', '1연습용 장갑', '1거인의 허리띠'], '명사수귀감']
# ['3', ['4쓸데없이 큰 지팡이', '3연습용 장갑', '3쇠사슬 조끼', '2음전자 망토', '1여신의 눈물', '1곡궁', '1거인의 허리띠', '1B.F. 대검'], '황혼']
# ['4', ['6쇠사슬 조끼', '3연습용 장갑', '2쓸데없이 큰 지팡이', '2거인의 허리띠', '2B.F. 대검', '1음전자 망토', '1여신의 눈물', '1곡궁'], '달빛사냥꾼']
# ['4', ['3연습용 장갑', '3쓸데없이 큰 지팡이', '3B.F. 대검', '2여신의 눈물', '2쇠사슬 조끼', '2거인의 허리띠', '1곡궁'], '달빛사냥꾼']
# ['6', ['3음전자 망토', '3쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2곡궁', '2B.F. 대검', '1뒤집개', '1거인의 허리띠'], '나무정령싸움꾼']
# ['1', ['6여신의 눈물', '3쓸데없이 큰 지팡이', '3B.F. 대검', '2뒤집개', '1음전자 망토', '1쇠사슬 조끼', '1곡궁', '1거인의 허리띠'], '나무정령요술사']
# ['5', ['4연습용 장갑', '4거인의 허리띠', '3쇠사슬 조끼', '3B.F. 대검', '2음전자 망토', '2여신의 눈물', '2곡궁', '1쓸데없이 큰 지팡이', '1뒤집개'], '달빛사냥꾼']
# ['1', ['6연습용 장갑', '4거인의 허리띠', '3곡궁', '2음전자 망토', '2여신의 눈물', '2쇠사슬 조끼', '2B.F. 대검', '1쓸데없이 큰 지팡이', '1뒤집개'], '달빛사냥꾼']
# ['1', ['4음전자 망토', '3쇠사슬 조끼', '3곡궁', '2연습용 장갑', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2거인의 허리띠', '2B.F. 대검'], '선봉대신비술사']
# ['7', ['3음전자 망토', '2연습용 장갑', '2곡궁', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1거인의 허리띠', '1B.F. 대검'], '명사수귀감']
# ['3', ['7거인의 허리띠', '5연습용 장갑', '5B.F. 대검', '2곡궁', '1음전자 망토', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼'], '달빛사냥꾼']
# ['5', ['2음전자 망토', '2쇠사슬 조끼', '2거인의 허리띠', '2B.F. 대검', '1연습용 장갑', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1곡궁'], '황혼']
# ['3', ['7연습용 장갑', '5거인의 허리띠', '4음전자 망토', '4쓸데없이 큰 지팡이', '4곡궁', '3쇠사슬 조끼', '3B.F. 대검', '1여신의 눈물', '1뒤집개'], '황혼']
# ['5', ['3음전자 망토', '3여신의 눈물', '3거인의 허리띠', '3B.F. 대검', '2연습용 장갑', '2쇠사슬 조끼', '1뒤집개', '1곡궁'], '나무정령요술사']
# ['5', ['4여신의 눈물', '3B.F. 대검', '1음전자 망토', '1연습용 장갑', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1뒤집개', '1곡궁', '1거인의 허리띠'], '나무정령요술사']
# ['8', ['3연습용 장갑', '2음전자 망토', '2쇠사슬 조끼', '2거인의 허리띠', '2B.F. 대검', '1여신의 눈물'], '달빛사냥꾼']
# ['3', ['3연습용 장갑', '3여신의 눈물', '2음전자 망토', '2곡궁', '2B.F. 대검', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1거인의 허리띠'], '나무정령요술사']
# ['1', ['6B.F. 대검', '5쓸데없이 큰 지팡이', '3음전자 망토', '3연습용 장갑', '3쇠사슬 조끼', '2거인의 허리띠', '1곡궁'], '황혼']
# ['5', ['5곡궁', '5B.F. 대검', '3음전자 망토', '3거인의 허리띠', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '1연습용 장갑'], '광신도']
# ['2', ['3연습용 장갑', '3쇠사슬 조끼', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2곡궁', '2거인의 허리띠', '2B.F. 대검', '1음전자 망토', '1뒤집개'], '달빛사냥꾼']
# ['1', ['3연습용 장갑', '3쇠사슬 조끼', '2쓸데없이 큰 지팡이', '2뒤집개', '2곡궁', '2거인의 허리띠', '2B.F. 대검', '1음전자 망토', '1여신의 눈물'], '달빛사냥꾼']
# ['8', ['8연습용 장갑', '4쓸데없이 큰 지팡이', '4곡궁', '3음전자 망토', '2뒤집개', '2거인의 허리띠', '1쇠사슬 조끼', '1B.F. 대검'], '나무정령싸움꾼']
# ['7', ['3쓸데없이 큰 지팡이', '2음전자 망토', '2여신의 눈물', '2거인의 허리띠', '2B.F. 대검', '1연습용 장갑', '1쇠사슬 조끼', '1곡궁'], '선봉대신비술사']
# ['6', ['3음전자 망토', '2연습용 장갑', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2거인의 허리띠', '2B.F. 대검', '1쇠사슬 조끼', '1뒤집개', '1곡궁'], '선봉대신비술사']
# ['2', ['4여신의 눈물', '3음전자 망토', '3B.F. 대검', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2거인의 허리띠', '1쇠사슬 조끼', '1곡궁'], '나무정령요술사']
# ['2', ['6여신의 눈물', '3연습용 장갑', '2음전자 망토', '2쓸데없이 큰 지팡이', '2거인의 허리띠', '2B.F. 대검', '1쇠사슬 조끼', '1곡궁'], '나무정령요술사']
# ['2', ['7연습용 장갑', '4거인의 허리띠', '3쇠사슬 조끼', '3곡궁', '3B.F. 대검', '2음전자 망토', '2쓸데없이 큰 지팡이', '1여신의 눈물'], '달빛사냥꾼']
# ['4', ['3음전자 망토', '3여신의 눈물', '3B.F. 대검', '2쇠사슬 조끼', '2곡궁', '2거인의 허리띠', '1쓸데없이 큰 지팡이'], '신성조율자']
# ['8', ['3B.F. 대검', '2연습용 장갑', '2여신의 눈물', '2쓸데없이 큰 지팡이', '1음전자 망토', '1쇠사슬 조끼', '1곡궁', '1거인의 허리띠'], '달빛사냥꾼']
# ['4', ['4쓸데없이 큰 지팡이', '3쇠사슬 조끼', '2음전자 망토', '2여신의 눈물', '2곡궁', '1연습용 장갑', '1뒤집개', '1거인의 허리띠', '1B.F. 대검'], '황혼']
# ['5', ['6여신의 눈물', '3거인의 허리띠', '3B.F. 대검', '2음전자 망토', '2연습용 장갑', '2쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1곡궁'], '달빛사냥꾼']
# ['1', ['4곡궁', '3음전자 망토', '3연습용 장갑', '3쇠사슬 조끼', '2뒤집개', '2거인의 허리띠', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1B.F. 대검'], '황혼']
# ['3', ['4여신의 눈물', '2음전자 망토', '2연습용 장갑', '2쇠사슬 조끼', '2곡궁', '2B.F. 대검', '1쓸데없이 큰 지팡이', '1거인의 허리띠'], '나무정령요술사']
# ['1', ['4여신의 눈물', '4쓸데없이 큰 지팡이', '4쇠사슬 조끼', '3거인의 허리띠', '2음전자 망토', '2연습용 장갑', '2B.F. 대검', '1곡궁'], '나무정령요술사']
# ['1', ['5거인의 허리띠', '5B.F. 대검', '3여신의 눈물', '3쓸데없이 큰 지팡이', '2음전자 망토', '2쇠사슬 조끼', '2곡궁', '1뒤집개'], '명사수귀감']
# ['6', ['4여신의 눈물', '2음전자 망토', '2연습용 장갑', '2거인의 허리띠', '2B.F. 대검', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼'], '나무정령요술사']
# ['7', ['3쇠사슬 조끼', '3거인의 허리띠', '1음전자 망토', '1연습용 장갑', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1곡궁', '1B.F. 대검'], '달빛사냥꾼']
# ['5', ['3여신의 눈물', '3쓸데없이 큰 지팡이', '3B.F. 대검', '2쇠사슬 조끼', '2거인의 허리띠', '1음전자 망토', '1연습용 장갑', '1곡궁'], '달빛사냥꾼']
# ['5', ['5곡궁', '4거인의 허리띠', '2여신의 눈물', '2쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1B.F. 대검'], '싸움꾼']
# ['8', ['2연습용 장갑', '2쓸데없이 큰 지팡이', '2곡궁', '2거인의 허리띠', '2B.F. 대검', '1음전자 망토', '1쇠사슬 조끼'], '달빛사냥꾼']
# ['1', ['4B.F. 대검', '3여신의 눈물', '3쓸데없이 큰 지팡이', '3곡궁', '2음전자 망토', '2쇠사슬 조끼', '1연습용 장갑', '1뒤집개'], '신성조율자']
# ['1', ['3연습용 장갑', '3여신의 눈물', '3쓸데없이 큰 지팡이', '3쇠사슬 조끼', '2음전자 망토', '2곡궁', '1거인의 허리띠', '1B.F. 대검'], '황혼']
# ['7', ['3음전자 망토', '3B.F. 대검', '2쓸데없이 큰 지팡이', '2곡궁', '2거인의 허리띠', '1연습용 장갑', '1여신의 눈물'], '명사수귀감']
# ['4', ['3음전자 망토', '3여신의 눈물', '3거인의 허리띠', '2쇠사슬 조끼', '2B.F. 대검', '1연습용 장갑', '1쓸데없이 큰 지팡이', '1뒤집개', '1곡궁'], '나무정령요술사']
# ['7', ['2여신의 눈물', '2곡궁', '2B.F. 대검', '1음전자 망토', '1연습용 장갑', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1뒤집개', '1거인의 허리띠'], '나무정령요술사']
# ['8', ['3여신의 눈물', '2쇠사슬 조끼', '1음전자 망토', '1연습용 장갑', '1곡궁', '1거인의 허리띠'], '나무정령요술사']
# ['3', ['7연습용 장갑', '4쓸데없이 큰 지팡이', '4쇠사슬 조끼', '3음전자 망토', '3여신의 눈물', '3거인의 허리띠', '2곡궁', '2B.F. 대검'], '선봉대신비술사']
# ['8', ['3뒤집개', '2여신의 눈물', '2거인의 허리띠', '1음전자 망토', '1연습용 장갑', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1곡궁', '1B.F. 대검'], '달빛사냥꾼']
# ['1', ['8쓸데없이 큰 지팡이', '4여신의 눈물', '3B.F. 대검', '2음전자 망토', '2뒤집개', '1연습용 장갑', '1쇠사슬 조끼', '1거인의 허리띠'], '나무정령요술사']
# ['4', ['4연습용 장갑', '4쇠사슬 조끼', '3거인의 허리띠', '2여신의 눈물', '1음전자 망토', '1쓸데없이 큰 지팡이', '1뒤집개', '1곡궁'], '달빛사냥꾼']
# ['1', ['3연습용 장갑', '3여신의 눈물', '3쓸데없이 큰 지팡이', '2음전자 망토', '2쇠사슬 조끼', '1곡궁', '1거인의 허리띠', '1B.F. 대검'], '나무정령요술사']
# ['4', ['4쓸데없이 큰 지팡이', '3거인의 허리띠', '2쇠사슬 조끼', '2곡궁', '2B.F. 대검', '1음전자 망토', '1연습용 장갑', '1여신의 눈물'], '달빛사냥꾼']
# ['1', ['5연습용 장갑', '4여신의 눈물', '3쓸데없이 큰 지팡이', '3곡궁', '3B.F. 대검', '2쇠사슬 조끼', '2거인의 허리띠', '1음전자 망토', '1뒤집개'], '결투가']
# ['1', ['3음전자 망토', '3여신의 눈물', '3쓸데없이 큰 지팡이', '3거인의 허리띠', '2연습용 장갑', '2B.F. 대검', '1뒤집개', '1곡궁'], '선봉대신비술사']
# ['6', ['4거인의 허리띠', '3연습용 장갑', '3곡궁', '2쇠사슬 조끼', '2B.F. 대검', '1여신의 눈물'], '싸움꾼']
# ['2', ['6여신의 눈물', '3곡궁', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2거인의 허리띠', '1음전자 망토', '1쇠사슬 조끼', '1B.F. 대검'], '나무정령요술사']
# ['8', ['3곡궁', '2음전자 망토', '1연습용 장갑', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1뒤집개', '1거인의 허리띠'], '나무정령싸움꾼']
# ['6', ['3쓸데없이 큰 지팡이', '3B.F. 대검', '2곡궁', '2거인의 허리띠', '1음전자 망토', '1여신의 눈물'], '나무정령싸움꾼']
# ['4', ['4음전자 망토', '3연습용 장갑', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2거인의 허리띠', '1곡궁', '1B.F. 대검'], '선봉대신비술사']
# ['2', ['4연습용 장갑', '3음전자 망토', '3여신의 눈물', '3쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2곡궁', '2B.F. 대검', '1뒤집개', '1거인의 허리띠'], '나무정령요술사']
# ['8', ['2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2뒤집개', '2곡궁', '2거인의 허리띠', '2B.F. 대검', '1음전자 망토', '1연습용 장갑'], '명사수귀감']
# ['1', ['3음전자 망토', '3연습용 장갑', '3여신의 눈물', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2거인의 허리띠', '2B.F. 대검', '1곡궁'], '선봉대신비술사']
# ['2', ['5연습용 장갑', '5거인의 허리띠', '3쇠사슬 조끼', '2음전자 망토', '2여신의 눈물', '2B.F. 대검', '1쓸데없이 큰 지팡이', '1곡궁'], '달빛사냥꾼']
# ['1', ['5음전자 망토', '3연습용 장갑', '3B.F. 대검', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2곡궁', '2거인의 허리띠', '1쇠사슬 조끼'], '달빛사냥꾼']
# ['7', ['3쇠사슬 조끼', '2곡궁', '2B.F. 대검', '1음전자 망토', '1연습용 장갑', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1거인의 허리띠'], '황혼']
# ['2', ['4쇠사슬 조끼', '4곡궁', '2음전자 망토', '2연습용 장갑', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2거인의 허리띠', '2B.F. 대검'], '황혼']
# ['4', ['3연습용 장갑', '3곡궁', '3거인의 허리띠', '3B.F. 대검', '2음전자 망토', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼'], '그림자닌자']
# ['5', ['4B.F. 대검', '3여신의 눈물', '3거인의 허리띠', '2쓸데없이 큰 지팡이', '2곡궁', '1음전자 망토', '1쇠사슬 조끼'], '달빛사냥꾼']
# ['5', ['4음전자 망토', '3연습용 장갑', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2B.F. 대검', '1여신의 눈물'], '조율자결투가']
# ['2', ['6쇠사슬 조끼', '4음전자 망토', '3곡궁', '2쓸데없이 큰 지팡이', '1연습용 장갑', '1여신의 눈물', '1거인의 허리띠', '1B.F. 대검'], '황혼']
# ['1', ['5B.F. 대검', '4음전자 망토', '4여신의 눈물', '4쓸데없이 큰 지팡이', '4곡궁', '2연습용 장갑', '2쇠사슬 조끼', '1거인의 허리띠'], '명사수귀감']
# ['3', ['4쓸데없이 큰 지팡이', '3연습용 장갑', '3여신의 눈물', '2음전자 망토', '2곡궁', '2거인의 허리띠', '1쇠사슬 조끼'], '선봉대신비술사']
# ['2', ['4거인의 허리띠', '3곡궁', '2음전자 망토', '2연습용 장갑', '2B.F. 대검', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼'], '그림자닌자']
# ['6', ['4B.F. 대검', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2곡궁', '2거인의 허리띠', '1음전자 망토', '1여신의 눈물', '1뒤집개'], '명사수귀감']
# ['7', ['6쇠사슬 조끼', '3음전자 망토', '2연습용 장갑', '2거인의 허리띠', '2B.F. 대검', '1여신의 눈물', '1쓸데없이 큰 지팡이'], '황혼']
# ['1', ['5음전자 망토', '3쓸데없이 큰 지팡이', '3거인의 허리띠', '2연습용 장갑', '2여신의 눈물', '2쇠사슬 조끼', '2뒤집개', '1B.F. 대검'], '선봉대신비술사']
# ['8', ['4B.F. 대검', '3거인의 허리띠', '1연습용 장갑', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1뒤집개'], '달빛사냥꾼']
# ['5', ['7여신의 눈물', '4곡궁', '3연습용 장갑', '2음전자 망토', '2쇠사슬 조끼', '2거인의 허리띠', '2B.F. 대검', '1쓸데없이 큰 지팡이', '1뒤집개'], '결투가']
# ['5', ['4거인의 허리띠', '4B.F. 대검', '2곡궁', '1음전자 망토', '1연습용 장갑', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1뒤집개'], '그림자닌자']
# ['7', ['3여신의 눈물', '2연습용 장갑', '2쇠사슬 조끼', '1음전자 망토', '1쓸데없이 큰 지팡이', '1곡궁', '1거인의 허리띠', '1B.F. 대검'], '나무정령요술사']
# ['3', ['3연습용 장갑', '3쓸데없이 큰 지팡이', '3곡궁', '2음전자 망토', '2여신의 눈물', '2거인의 허리띠', '2B.F. 대검', '1쇠사슬 조끼'], '선봉대신비술사']
# ['3', ['7B.F. 대검', '4연습용 장갑', '2음전자 망토', '2거인의 허리띠', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1곡궁'], '달빛사냥꾼']
# ['1', ['5여신의 눈물', '4쇠사슬 조끼', '3B.F. 대검', '2음전자 망토', '2연습용 장갑', '2거인의 허리띠', '1쓸데없이 큰 지팡이', '1곡궁'], '나무정령요술사']
# ['4', ['3연습용 장갑', '3여신의 눈물', '3쓸데없이 큰 지팡이', '2거인의 허리띠', '2B.F. 대검', '1음전자 망토', '1쇠사슬 조끼', '1곡궁'], '달빛사냥꾼']
# ['1', ['4여신의 눈물', '2음전자 망토', '2연습용 장갑', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2곡궁', '2B.F. 대검', '1뒤집개'], '나무정령요술사']
# ['8', ['4음전자 망토', '3쓸데없이 큰 지팡이', '2연습용 장갑', '1B.F. 대검'], '선봉대신비술사']
# ['2', ['5음전자 망토', '4여신의 눈물', '2연습용 장갑', '2곡궁', '2B.F. 대검', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1거인의 허리띠'], '나무정령요술사']
# ['4', ['5B.F. 대검', '3쓸데없이 큰 지팡이', '3쇠사슬 조끼', '2거인의 허리띠', '1연습용 장갑', '1여신의 눈물', '1곡궁'], '황혼']
# ['1', ['4음전자 망토', '4여신의 눈물', '4B.F. 대검', '2연습용 장갑', '2쇠사슬 조끼', '2곡궁', '1쓸데없이 큰 지팡이', '1거인의 허리띠'], '조율자결투가']
# ['1', ['4곡궁', '3음전자 망토', '3B.F. 대검', '2쇠사슬 조끼', '2거인의 허리띠', '1연습용 장갑', '1쓸데없이 큰 지팡이'], '신성조율자']
# ['6', ['3곡궁', '2음전자 망토', '2연습용 장갑', '2쇠사슬 조끼', '2B.F. 대검', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1거인의 허리띠'], '명사수귀감']
# ['7', ['6여신의 눈물', '5곡궁', '3쇠사슬 조끼', '2연습용 장갑', '2B.F. 대검', '1음전자 망토', '1쓸데없이 큰 지팡이', '1거인의 허리띠'], '나무정령요술사']
# ['6', ['6B.F. 대검', '2연습용 장갑', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '1음전자 망토', '1곡궁', '1거인의 허리띠'], '명사수귀감']
# ['7', ['5쇠사슬 조끼', '3곡궁', '2쓸데없이 큰 지팡이', '2거인의 허리띠', '1음전자 망토', '1여신의 눈물', '1뒤집개', '1B.F. 대검'], '싸움꾼']
# ['1', ['5쓸데없이 큰 지팡이', '5곡궁', '4연습용 장갑', '2음전자 망토', '2쇠사슬 조끼', '2뒤집개', '2거인의 허리띠', '1여신의 눈물', '1B.F. 대검'], '나무정령싸움꾼']
# ['1', ['7거인의 허리띠', '5곡궁', '4B.F. 대검', '3음전자 망토', '3연습용 장갑', '2여신의 눈물', '2쓸데없이 큰 지팡이'], '달빛사냥꾼']
# ['2', ['4쓸데없이 큰 지팡이', '4곡궁', '3음전자 망토', '3거인의 허리띠', '2여신의 눈물', '2쇠사슬 조끼', '2B.F. 대검', '1연습용 장갑'], '선봉대신비술사']
# ['1', ['4음전자 망토', '3연습용 장갑', '3여신의 눈물', '3거인의 허리띠', '2쇠사슬 조끼', '1쓸데없이 큰 지팡이', '1곡궁', '1B.F. 대검'], '달빛사냥꾼']
# ['1', ['3곡궁', '3거인의 허리띠', '2음전자 망토', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2B.F. 대검', '1연습용 장갑'], '명사수귀감']
# ['6', ['3곡궁', '3B.F. 대검', '2여신의 눈물', '2쓸데없이 큰 지팡이', '1음전자 망토', '1연습용 장갑', '1뒤집개', '1거인의 허리띠'], '나무정령싸움꾼']
# ['7', ['3연습용 장갑', '2음전자 망토', '2쇠사슬 조끼', '2B.F. 대검', '1여신의 눈물', '1쓸데없이 큰 지팡이', '1뒤집개', '1곡궁', '1거인의 허리띠'], '나무정령요술사']
# ['2', ['6연습용 장갑', '4B.F. 대검', '3여신의 눈물', '2음전자 망토', '2쇠사슬 조끼', '2곡궁', '1쓸데없이 큰 지팡이', '1뒤집개'], '조율자결투가']
# ['6', ['3여신의 눈물', '3쓸데없이 큰 지팡이', '2음전자 망토', '2쇠사슬 조끼', '2곡궁', '1뒤집개', '1B.F. 대검'], '나무정령요술사']
# ['7', ['2음전자 망토', '2연습용 장갑', '2곡궁', '2B.F. 대검', '1쓸데없이 큰 지팡이', '1쇠사슬 조끼', '1뒤집개', '1거인의 허리띠'], '나무정령싸움꾼']
# ['4', ['2음전자 망토', '2연습용 장갑', '2여신의 눈물', '2쓸데없이 큰 지팡이', '2쇠사슬 조끼', '2곡궁', '2B.F. 대검', '1뒤집개', '1거인의 허리띠'], '나무정령요술사']

# %% [markdown]
# ## 메인 조합을 불러오기

# %%
def find_meta(item_dict):

#     driver = wd.Chrome(executable_path="/mnt/c/Users/shurona/Documents/chromedriver.exe")
    url = 'https://lolchess.gg/meta'
#     driver.get(url)
    hdr = {'Accept-Language' : 'Ko_KR'}
    req = requests.get(url, headers = hdr)
    html = req.text
    soup = BeautifulSoup(html, 'html.parser')
    
    tp = soup.find("div",{"class" : "container-full"})
    
    #최종 저장 리스트
    final_set = []
    
    #각각의 내용을 저장할 장소
    title = {}
    Configuration = []
    champ_list = []
    items_list = []
    main_johap = []
    small_title = []
    #페이지의 메타를 정리해놓은 표에서 시너지 별로 표를 정리한다. 
    for i,v in enumerate(tp.select('div[class=guide-meta__deck]')):
        #sub 리스트 
        sub = []
        
        #공백 지우기 
        del_blank = v.find('div',{"class" : "guide-meta__deck__column name mr-3"}).text.strip()
    
        #데이터를 저장할 리스트들
        johap_name=''
        
        #조합 모으기
        for find_togle in v.select(".tft-hexagon-image"):
            num = (find_togle.get('data-tooltip-url')[-1])
            word = (find_togle.find('img', alt = True)['alt'])
            Configuration.append(str(num) + " " + word)
        
        #챔프 모으기 
        for find_champ in v.select(".tft-champion"):
            name = find_champ.find('img', alt=True)['alt']
            champ_list.append(name)

        #아이템 모으기
        for find_item in v.select(".tft-items"):
            t = find_item.select('img')
            if len(t) == 0:
                continue
            for trash in t:
                trash['alt']
        
        count = 0
        for index,value in enumerate(del_blank):
        
            if ord('가') <= ord(value) <= ord('힣'):
                if count == 0:
                    start = index
                count=1
            else:
                if count == 1:
                    johap_name = johap_name+(''.join(del_blank[start:index]))
                    count = 0
        if count == 1:
#             small_title.append(del_blank[start:])
            johap_name = johap_name+(del_blank[start:])
            
        small_title.append(johap_name)
            
        for item in v.find_all('div',{'class':'tft-items'}):
            items = item.find_all('img')
            if len(items) == 0:
                continue
            for tem in items:
                items_list.append(tem.get('alt'))
                
                
        sub.append(Configuration[:])
        sub.append(items_list[:])
        main_johap.append(sub[:])
#         title['구성'] = Configuration[:]
#         title['챔피언'] = champ_list[:]
#         title['아이템'] = items_list[:]

        final_set.append(title.copy())
        

        champ_list.clear()
        Configuration.clear()
        items_list.clear()
        title.clear()
        sub.clear()

    main_johap.append(small_title)
    return main_johap

# %%
final_set = find_meta(item_list)

# %%
for i in final_set[:14]:
    before = i.pop()
    after = decomposition_item(item_list,before)
    af = list(set(after))
    for index, value in enumerate(af):
        if value[0].isnumeric():
            break
        af_tp = af[index]
        af[index] = str(after.count(value))+af_tp
    i.append(af)

# %%
final_set
# Out:
# [[['3 조율자',
#    '3 달빛',
#    '3 사냥꾼',
#    '2 신성',
#    '2 영혼',
#    '2 신비술사',
#    '2 싸움꾼',
#    '1 닌자',
#    '1 추방자'],
#   ['1음전자 망토',
#    '3연습용 장갑',
#    '1쇠사슬 조끼',
#    '1곡궁',
#    '3B.F. 대검',
#    '2여신의 눈물',
#    '2쓸데없이 큰 지팡이',
#    '3거인의 허리띠']],
#  [['6 나무정령', '6 요술사', '2 싸움꾼'],
#   ['1뒤집개',
#    '4여신의 눈물',
#    '1쇠사슬 조끼',
#    '2연습용 장갑',
#    '1거인의 허리띠',
#    '1곡궁',
#    '2음전자 망토',
#    '2쓸데없이 큰 지팡이',
#    '2B.F. 대검']],
#  [['6 황혼', '1 황제', '2 선봉대', '2 귀감', '2 명사수'],
#   ['3쓸데없이 큰 지팡이',
#    '3쇠사슬 조끼',
#    '2연습용 장갑',
#    '1거인의 허리띠',
#    '1곡궁',
#    '1여신의 눈물',
#    '2음전자 망토',
#    '3B.F. 대검']],
#  [['4 조율자', '2 추방자', '4 결투가', '2 선지자', '2 신성', '2 신비술사', '1 닌자'],
#   ['2쇠사슬 조끼', '4여신의 눈물', '3연습용 장갑', '1쓸데없이 큰 지팡이', '3B.F. 대검', '3음전자 망토']],
#  [['6 명사수', '4 귀감', '1 황제', '3 대장군', '2 황혼', '1 닌자'],
#   ['2쇠사슬 조끼',
#    '2곡궁',
#    '4B.F. 대검',
#    '2연습용 장갑',
#    '1거인의 허리띠',
#    '1여신의 눈물',
#    '2음전자 망토',
#    '2쓸데없이 큰 지팡이']],
#  [['9 대장군', '1 우두머리', '1 황제', '2 싸움꾼', '2 귀감'],
#   ['1뒤집개',
#    '3쓸데없이 큰 지팡이',
#    '1쇠사슬 조끼',
#    '2연습용 장갑',
#    '1거인의 허리띠',
#    '1곡궁',
#    '1여신의 눈물',
#    '2음전자 망토',
#    '2B.F. 대검']],
#  [['9 나무정령', '1 우두머리', '4 싸움꾼', '2 사냥꾼'],
#   ['1뒤집개',
#    '2곡궁',
#    '3쓸데없이 큰 지팡이',
#    '1쇠사슬 조끼',
#    '2연습용 장갑',
#    '1거인의 허리띠',
#    '3B.F. 대검',
#    '1여신의 눈물',
#    '2음전자 망토']],
#  [['9 나무정령', '3 요술사', '2 싸움꾼'],
#   ['1뒤집개',
#    '3여신의 눈물',
#    '1음전자 망토',
#    '3쇠사슬 조끼',
#    '2연습용 장갑',
#    '1거인의 허리띠',
#    '1곡궁',
#    '1쓸데없이 큰 지팡이',
#    '3B.F. 대검']],
#  [['4 신비술사', '4 선봉대', '2 영혼', '2 황혼', '1 닌자'],
#   ['3쓸데없이 큰 지팡이',
#    '1쇠사슬 조끼',
#    '2거인의 허리띠',
#    '1곡궁',
#    '2연습용 장갑',
#    '2여신의 눈물',
#    '3음전자 망토',
#    '2B.F. 대검']],
#  [['6 신성', '3 조율자', '2 결투가', '2 신비술사', '1 닌자', '1 추방자'],
#   ['3여신의 눈물',
#    '2쇠사슬 조끼',
#    '1연습용 장갑',
#    '1거인의 허리띠',
#    '1쓸데없이 큰 지팡이',
#    '3B.F. 대검',
#    '2음전자 망토',
#    '3곡궁']],
#  [['8 결투가', '2 추방자', '2 선지자', '2 신성'],
#   ['1뒤집개',
#    '2쇠사슬 조끼',
#    '2곡궁',
#    '4여신의 눈물',
#    '1음전자 망토',
#    '2연습용 장갑',
#    '2거인의 허리띠',
#    '2B.F. 대검']],
#  [['9 광신도'],
#   ['2쇠사슬 조끼',
#    '1연습용 장갑',
#    '4B.F. 대검',
#    '2거인의 허리띠',
#    '1곡궁',
#    '2쓸데없이 큰 지팡이',
#    '4음전자 망토']],
#  [['4 그림자', '4 닌자', '1 번뇌', '2 조율자', '2 암살자', '1 추방자'],
#   ['4B.F. 대검', '2연습용 장갑', '1쇠사슬 조끼', '1여신의 눈물', '2음전자 망토', '3곡궁', '3거인의 허리띠']],
#  [['8 싸움꾼', '1 우두머리', '3 나무정령', '2 사냥꾼'],
#   ['2쇠사슬 조끼',
#    '2연습용 장갑',
#    '1여신의 눈물',
#    '3곡궁',
#    '1B.F. 대검',
#    '5거인의 허리띠',
#    '2쓸데없이 큰 지팡이']],
#  ['달빛사냥꾼',
#   '나무정령요술사',
#   '황혼',
#   '조율자결투가',
#   '명사수귀감',
#   '대장군',
#   '나무정령싸움꾼',
#   '나무정령요술사',
#   '선봉대신비술사',
#   '신성조율자',
#   '결투가',
#   '광신도',
#   '그림자닌자',
#   '싸움꾼']]

# %% [markdown]
# ## 셀레니움을 사용하여서 상위 티어의 전적 가져오기

# %%
#decks > div > section > div.col-12.col-xl-9

#soup를 받아오는 함수
def receive_soup(url, hdr):
    req = requests.get(url,headers = hdr)
    html = req.text
    return(BeautifulSoup(html, 'html.parser'))
    
#url을 받아오면 여기서 s
def get_info(url,hdr,driver):
    req = requests.get(url,headers = hdr)
    html = req.text
    soup = BeautifulSoup(html, 'html.parser')
    history = soup.find('div',{'class' : 'profile__match-history-v2__filters'}).select('a')[1]['href']
    url = history
    driver.get(url)
    for i in driver.find_elements_by_class_name('toggle-detail'):
        i.click()
        time.sleep(1)
    time.sleep(2)
    sp = BeautifulSoup(driver.page_source, 'html.parser')
    return sp
    
options = wd.ChromeOptions()
options.add_argument('--window-size=1920,1080')
options.add_argument('--headless')
options.add_argument('--disable-gpu')
driver = wd.Chrome(executable_path="/mnt/c/Users/shurona/Documents/chromedriver.exe", options=options)    
url = 'https://lolchess.gg/leaderboards'
hdr = {'Accept-Language' : 'Ko_KR', 'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36'}
req = requests.get(url, headers = hdr)
html = req.text
soup = BeautifulSoup(html, 'html.parser')
for i in soup.find('tbody').select('a'):
    sp = get_info(i['href'],hdr,driver)
    break

# %%
import itertools
count  = 1
for i in sp.find_all('div',{'class' : 'profile__match-history-v2__item__detail'}):
    for score, value in enumerate(i.find('tbody').find_all('tr')):
        print(count)
        count += 1
        arr=[]
        need_item=[]

        traits = value.select_one('td[class=traits]')
        champions = value.select_one('td[class=champions]')  
        for kinds in traits.select('.tft-hexagon-image'):
            print(kinds.find('img')['alt'], end = ' ')
        print()
        for champ in champions.select('.champions__image'):
            print(champ.find('img')['alt'], end = ' ')
        print()
        for items in champions.select('.champions__items'):
            if items.find('img') != None:
                for i in items.select('img'):
                    arr.append(i['data-original-title'])
#         print(arr)
        for big in arr:
            if big in item_list.keys():
                for divide in item_list[big]:
                    need_item.append(divide)
        print(list(set(need_item)))
        
        
        break
        print()
# Out:
# 1
# 1 황제 5 황혼 2 귀감 2 조율자 2 신비술사 2 명사수 1 추방자 1 닌자
# 니달리 쓰레쉬 쉔 진 카시오페아 리븐 아지르 요네
# ['쓸데없이 큰 지팡이', '쇠사슬 조끼', '곡궁', '거인의 허리띠', '뒤집개', 'B.F. 대검', '음전자 망토', '여신의 눈물']
# 2
# 6 명사수 1 황제 2 황혼 2 신비술사 1 추방자
# 니달리 베인 티모 징크스 진 카시오페아 아지르 요네 질리언
# ['쓸데없이 큰 지팡이', '쇠사슬 조끼', '연습용 장갑', '곡궁', '거인의 허리띠', 'B.F. 대검', '음전자 망토', '여신의 눈물']
# 3
# 1 우두머리 4 암살자 3 달빛 3 나무정령 2 싸움꾼 2 현혹술사 1 닌자
# 마오카이 다이애나 리산드라 파이크 아칼리 카타리나 세트 이즈리얼
# ['쓸데없이 큰 지팡이', '쇠사슬 조끼', '곡궁', '거인의 허리띠', '뒤집개', 'B.F. 대검', '음전자 망토']
# 4
# 6 신비술사 1 황제 3 요술사 2 황혼 2 현혹술사 1 닌자
# 잔나 럭스 유미 쉔 카시오페아 릴리아 아지르 이즈리얼 질리언
# ['쓸데없이 큰 지팡이', '쇠사슬 조끼', '연습용 장갑', '곡궁', '거인의 허리띠', '뒤집개', 'B.F. 대검', '음전자 망토', '여신의 눈물']
# 5
# 1 우두머리 1 황제 6 대장군 3 귀감 2 암살자 2 싸움꾼
# 니달리 바이 자르반 4세 파이크 카타리나 리븐 세트 아지르
# ['쓸데없이 큰 지팡이', '쇠사슬 조끼', '연습용 장갑', '거인의 허리띠', 'B.F. 대검', '음전자 망토', '여신의 눈물']
# 6
# 1 우두머리 3 사냥꾼 3 나무정령 3 요술사 2 조율자 2 싸움꾼 2 신비술사 1 추방자 1 닌자
# 룰루 쉔 워윅 애쉬 릴리아 요네 질리언 세트
# ['쓸데없이 큰 지팡이', '쇠사슬 조끼', '연습용 장갑', '곡궁', '거인의 허리띠', '뒤집개', 'B.F. 대검', '음전자 망토', '여신의 눈물']
# 7
# 8 결투가 2 추방자 1 황제 3 신성
# 피오라 야스오 잭스 신 짜오 칼리스타 질리언 리 신 아지르 요네
# ['쓸데없이 큰 지팡이', '쇠사슬 조끼', '연습용 장갑', '곡궁', '거인의 허리띠', '뒤집개', 'B.F. 대검']
# 8
# 6 귀감 1 황제 3 광신도 3 대장군 2 암살자 1 닌자
# 엘리스 자르반 4세 파이크 카타리나 케넨 리븐 아트록스 아지르
# ['쓸데없이 큰 지팡이', '쇠사슬 조끼', '연습용 장갑', '곡궁', '거인의 허리띠', 'B.F. 대검', '음전자 망토', '여신의 눈물']
# 9
# 9 요술사 3 나무정령
# 트위스티드 페이트 나미 룰루 애니 베이가 아리 릴리아 이즈리얼
# ['쓸데없이 큰 지팡이', '쇠사슬 조끼', '연습용 장갑', '거인의 허리띠', '뒤집개', 'B.F. 대검', '여신의 눈물']
# 10
# 1 우두머리 1 황제 3 나무정령 2 조율자 2 신비술사 2 신성 2 싸움꾼 2 귀감 2 사냥꾼 1 추방자 1 닌자
# 유미 쉔 애쉬 워윅 릴리아 이즈리얼 리 신 세트 아지르 요네
# ['쓸데없이 큰 지팡이', '쇠사슬 조끼', '연습용 장갑', '곡궁', '거인의 허리띠', '뒤집개', 'B.F. 대검', '음전자 망토', '여신의 눈물']

# %%
a = [1,2,3]
lambda a : a+2
# Out:
# <function __main__.<lambda>(a)>

# %%
# driver = wd.Chrome(executable_path="/mnt/c/Users/shurona/Documents/chromedriver.exe")
# url = 'https://lolchess.gg/decks'
# driver.get(url)
# driver.find_element_by_css_selector('.decks-header__button').click()
# time.sleep(5)
# html = driver.page_source
