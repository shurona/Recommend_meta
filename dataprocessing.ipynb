# %%
from tqdm import tqdm
from sklearn.neighbors import KNeighborsClassifier

import pandas as pd
import numpy as np

import itertools
import time
import copy
import re

# %%
dataset = pd.read_csv('itemlist_ver1.csv')

# %%
dataset.head()
# Out:
#    rank  B.F. 대검  거인의 허리띠  곡궁  뒤집개  쇠사슬 조끼  쓸데없이 큰 지팡이  여신의 눈물  연습용 장갑  \
# 0     6        2        0   3    0       2           1       1       4
# 1     6        2        0   2    0       2           1       2       2
# 2     3        3        1   3    0       2           3       3       3
# 3     2        1        4   5    0       1           0       2       5
# 4     3        3        0   1    0       1           3       3       3
#
#    음전자 망토      조합
# 0       4  조율자결투가
# 1       1   명사수귀감
# 2       0   신성조율자
# 3       6   그림자닌자
# 4       2   달빛사냥꾼

# %%
tp = dataset.drop(['조합'], axis=1)

# %%
tp
# Out:
#      rank  B.F. 대검  거인의 허리띠  곡궁  뒤집개  쇠사슬 조끼  쓸데없이 큰 지팡이  여신의 눈물  연습용 장갑  \
# 0       6        2        0   3    0       2           1       1       4
# 1       6        2        0   2    0       2           1       2       2
# 2       3        3        1   3    0       2           3       3       3
# 3       2        1        4   5    0       1           0       2       5
# 4       3        3        0   1    0       1           3       3       3
# ..    ...      ...      ...  ..  ...     ...         ...     ...     ...
# 995     4        4        0   4    0       2           2       1       1
# 996     5        1        1   1    0       3           3       2       0
# 997     1        2        2   5    0       3           2       5       0
# 998     7        4        1   1    0       4           3       0       3
# 999     4        1        3   2    1       3           1       3       2
#
#      음전자 망토
# 0         4
# 1         1
# 2         0
# 3         6
# 4         2
# ...

# %%
knn = KNeighborsClassifier(n_neighbors=3)

# %%
x = tp

# %%
y = dataset['조합']

# %%
knn.fit(x,y)
# Out:
# KNeighborsClassifier(n_neighbors=3)
